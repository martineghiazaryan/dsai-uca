# %% [markdown]
# # Lab about missing value, sampling and threshold ajustement
#
# Build a pipeline with:
# - Impute or delete of missing values (transformer or sampler)
# - Adjust classes (RUS, ROS, SMOTE strategy)
# - One hot encode categorical features and normalize numerical features (transformer)
# - Ajust threshold to maximize accuracy (predictor with logistic regression)
#     - fit method select best threshold for accuracy score
#     - predict method use the previously chosen threshold
# - Put on slack your best score
#
# If you have time, you can do a feature selection step.

# %% [markdown]
# ## Dataset
#
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things.
#
# You'll build a model to predict hotel cancellations with a binary classifier.

# %%
import pandas as pd
import numpy as np

# %%
hotel = pd.read_csv('data/hotel_bookings.csv')

# %%
X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

# %% [markdown]
# ## It's your turn

# %%
from sklearn.metrics import accuracy_score

from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif

from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler

from sklearn.linear_model import LogisticRegression
from sklearn.base import BaseEstimator

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from imblearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

transformer_num = Pipeline([
    ("imp", SimpleImputer(strategy="mean")), # there are a few missing values
    ("enc", StandardScaler()),
])
transformer_cat = Pipeline([
    ("imp", SimpleImputer(strategy="constant", fill_value="NA")),
    ("enc", OneHotEncoder(handle_unknown='ignore', sparse=False)),
])

pre = ColumnTransformer(transformers=[
    ("num", transformer_num, features_num),
    ("cat", transformer_cat, ["hotel"])
])

class myLogisticRegression(BaseEstimator):
    def __init__(self, max_iter=5000):
        self.max_iter = max_iter
        self.thresholds = np.linspace(0, 1.00, 101)
        self.clf = LogisticRegression(max_iter=self.max_iter)
    
    def fit(self, X, y):
        self.clf.fit(X, y)
        y_ = self.clf.predict_proba(X)[:, 1]  
        ACC = [accuracy_score(y, y_>=t) for t in self.thresholds]
        self.threshold = self.thresholds[np.argmax(ACC)]
        return self.clf

    def predict(self, X, y=None):
        return self.clf.predict_proba(X)[:, 1]>=self.threshold
    
    def score(self, X, y):
        return accuracy_score(y, self.predict(X))
    
pipeline = Pipeline([
    ("pre", pre),
    ("nb_features", PCA()),
    ("sampling", RandomOverSampler(sampling_strategy="auto")),
    ("clf", myLogisticRegression(False))
])

pipeline
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imp',
#                                                                    SimpleImputer()),
#                                                                   ('enc',
#                                                                    StandardScaler())]),
#                                                   ['lead_time',
#                                                    'arrival_date_week_number',
#                                                    'arrival_date_day_of_month',
#                                                    'stays_in_weekend_nights',
#                                                    'stays_in_week_nights',
#                                                    'adults', 'children',
#                                                    'babies',
#                                                    'is_repeated_guest',
#                                                    'previous_cancellations',
#                                                    'previous_bookings_not_canceled',
#                                                    'required_car_parking_spaces',
#                                                    'total_of_special_requests',
#                                                    'adr']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imp',
#                                                                    SimpleImputer(fill_value='NA',
#                                                                                  strategy='constant')),
#                                                                   ('enc',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['hotel'])])),
#                 ('nb_features', PCA()), ('sampling', RandomOverSampler()),
#                 ('clf', myLogisticRegression(max_iter=False))])

# %%
# stratify - make sure classes are evenlly represented across splits
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, train_size=0.75)

# %%
from sklearn.model_selection import GridSearchCV

params = {
   'nb_features': [None, PCA(), PCA(10), SelectKBest(f_classif, k=10), SelectKBest(mutual_info_classif, k=10)],
   'sampling':[None, RandomOverSampler(sampling_strategy=1.0), RandomUnderSampler(sampling_strategy=1.0), SMOTE(sampling_strategy=1.0)],
   'clf':[myLogisticRegression(max_iter=20000), LogisticRegression(max_iter=20000)], 
}
grid = GridSearchCV(pipeline, params, cv=5, scoring="accuracy", refit=True, verbose=2)
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print("Best: {:.3f} using {}".format(
    grid.best_score_, 
    grid.best_params_
))
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   0.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.2s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.4s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   1.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   1.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   3.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   2.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   2.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   2.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   2.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.6s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.6s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   3.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   3.4s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   1.2s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   1.2s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.3s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.2s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.2s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   2.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   2.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   2.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   2.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   2.3s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   1.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   1.0s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   5.6s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   3.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   3.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   5.9s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   8.2s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   6.4s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   6.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   6.2s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   6.2s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   6.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   6.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   6.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   6.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   6.1s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.8s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   7.6s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   7.4s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   7.7s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   8.4s
# [CV] END clf=myLogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   7.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=None; total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.2s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.2s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.2s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   1.9s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   2.0s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   2.0s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   2.0s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=None, sampling=SMOTE(sampling_strategy=1.0); total time=   1.9s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.0s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.1s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.1s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.1s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.1s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=None; total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   1.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   1.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   1.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   1.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=PCA(n_components=10), sampling=SMOTE(sampling_strategy=1.0); total time=   1.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=None; total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   0.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.2s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.2s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   0.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.0s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   1.9s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   1.8s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   2.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(), sampling=SMOTE(sampling_strategy=1.0); total time=   1.9s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   5.6s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   5.6s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   5.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   5.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=None; total time=   5.6s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   5.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   5.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   5.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   5.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomOverSampler(sampling_strategy=1.0); total time=   5.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.4s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.5s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=RandomUnderSampler(sampling_strategy=1.0); total time=   5.3s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   6.7s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   7.2s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   6.8s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   8.1s
# [CV] END clf=LogisticRegression(max_iter=20000), nb_features=SelectKBest(score_func=<function mutual_info_classif at 0x7fc7a40ba0d0>), sampling=SMOTE(sampling_strategy=1.0); total time=   6.9s
# Best: 0.729 using {'clf': myLogisticRegression(max_iter=20000), 'nb_features': PCA(), 'sampling': None}

# %%
cv_results = grid.cv_results_
scores_df = pd.DataFrame(cv_results)
scores_df[['param_nb_features', 'param_sampling', 'param_clf', 'mean_test_score', 'std_test_score']].sort_values('mean_test_score', ascending=False).head(40)
# Out:
#                                     param_nb_features  \
# 4                                               PCA()
# 0                                                None
# 24                                              PCA()
# 20                                               None
# 16  SelectKBest(score_func=<function mutual_info_c...
# 36  SelectKBest(score_func=<function mutual_info_c...
# 12                                      SelectKBest()
# 32                                      SelectKBest()
# 3                                                None
# 2                                                None
# 1                                                None
# 7                                               PCA()
# 6                                               PCA()
# 5                                               PCA()
# 28                               PCA(n_components=10)
# 8                                PCA(n_components=10)
# 17  SelectKBest(score_func=<function mutual_info_c...
# 26                                              PCA()
# 22                                               None
# 25                                              PCA()
# 23                                               None
# 27                                              PCA()
# 21                                               None
# 19  SelectKBest(score_func=<function mutual_info_c...
# 38  SelectKBest(score_func=<function mutual_info_c...
# 39  SelectKBest(score_func=<function mutual_info_c...
# 18  SelectKBest(score_func=<function mutual_info_c...
# 13                                      SelectKBest()
# 34                                      SelectKBest()
# 14                                      SelectKBest()
# 33                                      SelectKBest()
# 35                                      SelectKBest()
# 37  SelectKBest(score_func=<function mutual_info_c...
# 15                                      SelectKBest()
# 31                               PCA(n_components=10)
# 29                               PCA(n_components=10)
# 30                               PCA(n_components=10)
# 11                               PCA(n_components=10)
# 9                                PCA(n_components=10)
# 10                               PCA(n_components=10)
#
#                                param_sampling  \
# 4                                        None
# 0                                        None
# 24                                       None
# 20                                       None
# 16                                       None
# 36                                       None
# 12                                       None
# 32                                       None
# 3                SMOTE(sampling_strategy=1.0)
# 2   RandomUnderSampler(sampling_strategy=1.0)
# 1    RandomOverSampler(sampling_strategy=1.0)
# 7                SMOTE(sampling_strategy=1.0)
# 6   RandomUnderSampler(sampling_strategy=1.0)
# 5    RandomOverSampler(sampling_strategy=1.0)
# 28                                       None
# 8                                        None
# 17   RandomOverSampler(sampling_strategy=1.0)
# 26  RandomUnderSampler(sampling_strategy=1.0)
# 22  RandomUnderSampler(sampling_strategy=1.0)
# 25   RandomOverSampler(sampling_strategy=1.0)
# 23               SMOTE(sampling_strategy=1.0)
# 27               SMOTE(sampling_strategy=1.0)
# 21   RandomOverSampler(sampling_strategy=1.0)
# 19               SMOTE(sampling_strategy=1.0)
# 38  RandomUnderSampler(sampling_strategy=1.0)
# 39               SMOTE(sampling_strategy=1.0)
# 18  RandomUnderSampler(sampling_strategy=1.0)
# 13   RandomOverSampler(sampling_strategy=1.0)
# 34  RandomUnderSampler(sampling_strategy=1.0)
# 14  RandomUnderSampler(sampling_strategy=1.0)
# 33   RandomOverSampler(sampling_strategy=1.0)
# 35               SMOTE(sampling_strategy=1.0)
# 37   RandomOverSampler(sampling_strategy=1.0)
# 15               SMOTE(sampling_strategy=1.0)
# 31               SMOTE(sampling_strategy=1.0)
# 29   RandomOverSampler(sampling_strategy=1.0)
# 30  RandomUnderSampler(sampling_strategy=1.0)
# 11               SMOTE(sampling_strategy=1.0)
# 9    RandomOverSampler(sampling_strategy=1.0)
# 10  RandomUnderSampler(sampling_strategy=1.0)
#
#                                param_clf  mean_test_score  std_test_score
# 4   myLogisticRegression(max_iter=20000)         0.728585        0.004435
# 0   myLogisticRegression(max_iter=20000)         0.728518        0.004318
# 24    LogisticRegression(max_iter=20000)         0.727614        0.003923
# 20    LogisticRegression(max_iter=20000)         0.727614        0.003923
# 16  myLogisticRegression(max_iter=20000)         0.726631        0.005682
# 36    LogisticRegression(max_iter=20000)         0.726240        0.003738
# 12  myLogisticRegression(max_iter=20000)         0.725291        0.003517
# 32    LogisticRegression(max_iter=20000)         0.725079        0.003886
# 3   myLogisticRegression(max_iter=20000)         0.716066        0.004715
# 2   myLogisticRegression(max_iter=20000)         0.715519        0.006872
# 1   myLogisticRegression(max_iter=20000)         0.715240        0.007024
# 7   myLogisticRegression(max_iter=20000)         0.715084        0.005327
# 6   myLogisticRegression(max_iter=20000)         0.714860        0.006103
# 5   myLogisticRegression(max_iter=20000)         0.714514        0.001535
# 28    LogisticRegression(max_iter=20000)         0.708427        0.003429
# 8   myLogisticRegression(max_iter=20000)         0.708405        0.003402
# 17  myLogisticRegression(max_iter=20000)         0.704641        0.002869
# 26    LogisticRegression(max_iter=20000)         0.702989        0.001899
# 22    LogisticRegression(max_iter=20000)         0.702977        0.002239
# 25    LogisticRegression(max_iter=20000)         0.702821        0.002039
# 23    LogisticRegression(max_iter=20000)         0.702776        0.002670
# 27    LogisticRegression(max_iter=20000)         0.702754        0.002787
# 21    LogisticRegression(max_iter=20000)         0.702609        0.002116
# 19  myLogisticRegression(max_iter=20000)         0.702586        0.004210
# 38    LogisticRegression(max_iter=20000)         0.702330        0.003224
# 39    LogisticRegression(max_iter=20000)         0.701604        0.004021
# 18  myLogisticRegression(max_iter=20000)         0.700755        0.003585
# 13  myLogisticRegression(max_iter=20000)         0.700130        0.006115
# 34    LogisticRegression(max_iter=20000)         0.699582        0.003557
# 14  myLogisticRegression(max_iter=20000)         0.699527        0.005550
# 33    LogisticRegression(max_iter=20000)         0.699404        0.003397
# 35    LogisticRegression(max_iter=20000)         0.699314        0.003396
# 37    LogisticRegression(max_iter=20000)         0.699124        0.003248
# 15  myLogisticRegression(max_iter=20000)         0.698834        0.004118
# 31    LogisticRegression(max_iter=20000)         0.694635        0.002282
# 29    LogisticRegression(max_iter=20000)         0.693998        0.002119
# 30    LogisticRegression(max_iter=20000)         0.693741        0.001984
# 11  myLogisticRegression(max_iter=20000)         0.687376        0.003413
# 9   myLogisticRegression(max_iter=20000)         0.686940        0.002980
# 10  myLogisticRegression(max_iter=20000)         0.686214        0.002964
