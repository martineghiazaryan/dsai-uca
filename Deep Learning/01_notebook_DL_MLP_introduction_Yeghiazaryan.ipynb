# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction-:-a-visual-intuition-of-activation-functions" data-toc-modified-id="Introduction-:-a-visual-intuition-of-activation-functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction : a visual intuition of activation functions</a></span></li><li><span><a href="#Build-an-MLP-to-classify-MNIST-images" data-toc-modified-id="Build-an-MLP-to-classify-MNIST-images-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Build an MLP to classify MNIST images</a></span></li></ul></div>

# %% [markdown]
# # Introduction to the Multi Layer Perceptron

# %% [markdown]
# ## Introduction : a visual intuition of activation functions

# %% [markdown]
# Using a regression task on the sinus function, we'll try to get an intuition of the effect of activation functions.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping

# %%
X = np.arange(-3*np.pi,3*np.pi,0.01)
y = np.sin(X)

plt.figure(figsize=(13,8))
plt.plot(X, y, label='sinus', color='red')
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

plt.figure(figsize=(13,8))
plt.scatter(X_train, y_train, alpha = 0.03, label='training data')
plt.scatter(X_test, y_test,alpha=0.5,label='testing data')

plt.legend()
plt.show()

# %% [markdown]
# $$[TODO - Students]$$
#
# * Build a model with 1 hidden layer in 1 dimension and train it on x_train, y_train.
# * What activation should we use for ouput layer ?
# * What loss should we use ?
#
# * Try different activations for the hidden layer and plot the predictions obtained on x_test
# * Plot also a learning curve

# %%
inputs = Input(shape=(1,), name="inputs")

# One hidden layer with 1 neuron
x_sig = Dense(1, activation="sigmoid", name="layer_1")(inputs)
out_sig = Dense(1, activation="linear", name="output")(x_sig)

model = Model(inputs, out_sig)

model.compile(loss="mse", optimizer="adam")

model.summary()

history = model.fit(X_train, y_train, epochs=100, validation_split=0.33)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 1)]               0
#
#  layer_1 (Dense)             (None, 1)                 2
#
#  output (Dense)              (None, 1)                 2
#
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 7ms/step - loss: 0.5007 - val_loss: 0.5218
# Epoch 2/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4910 - val_loss: 0.5096
# Epoch 3/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4843 - val_loss: 0.5027
# Epoch 4/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.4813 - val_loss: 0.4966
# Epoch 5/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4790 - val_loss: 0.4945
# Epoch 6/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4782 - val_loss: 0.4922
# Epoch 7/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4775 - val_loss: 0.4915
# Epoch 8/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4771 - val_loss: 0.4900
# Epoch 9/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4767 - val_loss: 0.4896
# Epoch 10/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4765 - val_loss: 0.4890
# Epoch 11/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4762 - val_loss: 0.4886
# Epoch 12/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4761 - val_loss: 0.4884
# Epoch 13/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4759 - val_loss: 0.4876
# Epoch 14/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4755 - val_loss: 0.4877
# Epoch 15/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4754 - val_loss: 0.4876
# Epoch 16/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4753 - val_loss: 0.4875
# Epoch 17/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4750 - val_loss: 0.4870
# Epoch 18/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4748 - val_loss: 0.4868
# Epoch 19/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4747 - val_loss: 0.4866
# Epoch 20/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4745 - val_loss: 0.4864
# Epoch 21/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4745 - val_loss: 0.4868
# Epoch 22/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4741 - val_loss: 0.4864
# Epoch 23/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4740 - val_loss: 0.4860
# Epoch 24/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4739 - val_loss: 0.4864
# Epoch 25/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4738 - val_loss: 0.4855
# Epoch 26/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4735 - val_loss: 0.4856
# Epoch 27/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4734 - val_loss: 0.4855
# Epoch 28/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4733 - val_loss: 0.4852
# Epoch 29/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4732 - val_loss: 0.4855
# Epoch 30/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4731 - val_loss: 0.4851
# Epoch 31/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4729 - val_loss: 0.4849
# Epoch 32/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4728 - val_loss: 0.4850
# Epoch 33/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4726 - val_loss: 0.4847
# Epoch 34/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4725 - val_loss: 0.4842
# Epoch 35/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4724 - val_loss: 0.4842
# Epoch 36/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4723 - val_loss: 0.4841
# Epoch 37/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4722 - val_loss: 0.4840
# Epoch 38/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4720 - val_loss: 0.4843
# Epoch 39/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4720 - val_loss: 0.4840
# Epoch 40/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4719 - val_loss: 0.4840
# Epoch 41/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4719 - val_loss: 0.4838
# Epoch 42/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4717 - val_loss: 0.4836
# Epoch 43/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4718 - val_loss: 0.4837
# Epoch 44/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4714 - val_loss: 0.4838
# Epoch 45/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4714 - val_loss: 0.4836
# Epoch 46/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4714 - val_loss: 0.4837
# Epoch 47/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4713 - val_loss: 0.4830
# Epoch 48/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4712 - val_loss: 0.4831
# Epoch 49/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4711 - val_loss: 0.4831
# Epoch 50/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4710 - val_loss: 0.4830
# Epoch 51/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4711 - val_loss: 0.4828
# Epoch 52/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4709 - val_loss: 0.4828
# Epoch 53/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4712 - val_loss: 0.4835
# Epoch 54/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4709 - val_loss: 0.4830
# Epoch 55/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4707 - val_loss: 0.4829
# Epoch 56/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4709 - val_loss: 0.4831
# Epoch 57/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4705 - val_loss: 0.4824
# Epoch 58/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4706 - val_loss: 0.4826
# Epoch 59/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4705 - val_loss: 0.4827
# Epoch 60/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4703 - val_loss: 0.4825
# Epoch 61/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.4703 - val_loss: 0.4820
# Epoch 62/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4703 - val_loss: 0.4821
# Epoch 63/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4702 - val_loss: 0.4822
# Epoch 64/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4701 - val_loss: 0.4822
# Epoch 65/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4700 - val_loss: 0.4821
# Epoch 66/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4702 - val_loss: 0.4822
# Epoch 67/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4701 - val_loss: 0.4827
# Epoch 68/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4701 - val_loss: 0.4817
# Epoch 69/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4698 - val_loss: 0.4819
# Epoch 70/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4698 - val_loss: 0.4823
# Epoch 71/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4697 - val_loss: 0.4818
# Epoch 72/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4697 - val_loss: 0.4822
# Epoch 73/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4696 - val_loss: 0.4816
# Epoch 74/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4696 - val_loss: 0.4817
# Epoch 75/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4695 - val_loss: 0.4817
# Epoch 76/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.4695 - val_loss: 0.4819
# Epoch 77/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4696 - val_loss: 0.4812
# Epoch 78/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4695 - val_loss: 0.4818
# Epoch 79/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4693 - val_loss: 0.4818
# Epoch 80/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4694 - val_loss: 0.4816
# Epoch 81/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4695 - val_loss: 0.4813
# Epoch 82/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4693 - val_loss: 0.4816
# Epoch 83/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4692 - val_loss: 0.4817
# Epoch 84/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4691 - val_loss: 0.4820
# Epoch 85/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4691 - val_loss: 0.4812
# Epoch 86/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4691 - val_loss: 0.4816
# Epoch 87/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4690 - val_loss: 0.4811
# Epoch 88/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4690 - val_loss: 0.4807
# Epoch 89/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4690 - val_loss: 0.4814
# Epoch 90/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4691 - val_loss: 0.4807
# Epoch 91/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4688 - val_loss: 0.4813
# Epoch 92/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4688 - val_loss: 0.4814
# Epoch 93/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4690 - val_loss: 0.4816
# Epoch 94/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4688 - val_loss: 0.4811
# Epoch 95/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4687 - val_loss: 0.4812
# Epoch 96/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4687 - val_loss: 0.4810
# Epoch 97/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4690 - val_loss: 0.4805
# Epoch 98/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4688 - val_loss: 0.4815
# Epoch 99/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4686 - val_loss: 0.4806
# Epoch 100/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.4685 - val_loss: 0.4809

# %%
# Plot leaning cuve
plt.figure(figsize=(13,8))
plt.plot(history.history['loss'])
plt.show()

# %%
def plot_prediction(title, model):
    y_hat_test = model.predict(X_test)

    plt.figure()
    plt.scatter(X_test, y_test, label = 'ground_truth', alpha=0.1)
    plt.scatter(X_test, y_hat_test, label = 'predicted', alpha=0.5)
    plt.legend()
    
    plt.title(title)
    plt.show()

# %%
plot_prediction("my title", model)
# Out:
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# $$[TODO - Students]$$
#
# Try adding layers and increasing the layers dimension to better fit the test data. You can use the following function to quickly build your models.
#
# * Try different n_layers (for example 1, 10, 100)
# * Try different hidden_dim (for example 32, 128, 256, 512)
# * Try different bach size
# * Try to understand the `patience` parameters of early stopping

# %%
def build_sin_regression(activation, n_layers, hidden_dim):
    input = Input(shape=(1,), name='input')

    for i in range(n_layers):
      if i==0:
        x = Dense(input_shape=(1,), units=hidden_dim, activation=activation, name='layer_'+str(i))(input)
      else:
        x = Dense(units=hidden_dim, activation=activation, name='layer_'+str(i))(x)

    output = Dense(1, activation='linear', name='output')(x)
    model = Model(input, output, name = 'sinus_regression')
    return model

# %%
n_layers_val = [1, 10, 100]
hidden_dim_val = [32, 128, 256, 512]
batch_size_val = [16, 24]

# %%
model = build_sin_regression(activation = 'sigmoid', n_layers = n_layers_val[1], hidden_dim = hidden_dim_val[1])
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sinus_regression"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 1)]               0
#
#  layer_0 (Dense)             (None, 128)               256
#
#  layer_1 (Dense)             (None, 128)               16512
#
#  layer_2 (Dense)             (None, 128)               16512
#
#  layer_3 (Dense)             (None, 128)               16512
#
#  layer_4 (Dense)             (None, 128)               16512
#
#  layer_5 (Dense)             (None, 128)               16512
#
#  layer_6 (Dense)             (None, 128)               16512
#
#  layer_7 (Dense)             (None, 128)               16512
#
#  layer_8 (Dense)             (None, 128)               16512
#
#  layer_9 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 148,993
# Trainable params: 148,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model)

# %%
callbacks_list = [EarlyStopping(monitor='val_loss', min_delta=0.005, patience=20, verbose=2, mode='min', restore_best_weights=True)
                 ]

history = model.fit(X_train, y_train, validation_split = 0.1, callbacks=callbacks_list, batch_size=32, epochs=20)
# Out:
# Epoch 1/20
# 48/48 [==============================] - 1s 9ms/step - loss: 0.5358 - val_loss: 0.5288
# Epoch 2/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5142 - val_loss: 0.5532
# Epoch 3/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5085 - val_loss: 0.5513
# Epoch 4/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5110 - val_loss: 0.5470
# Epoch 5/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5041 - val_loss: 0.5317
# Epoch 6/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5123 - val_loss: 0.5327
# Epoch 7/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5045 - val_loss: 0.5297
# Epoch 8/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5023 - val_loss: 0.5878
# Epoch 9/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5086 - val_loss: 0.5285
# Epoch 10/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5030 - val_loss: 0.5397
# Epoch 11/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5019 - val_loss: 0.5283
# Epoch 12/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4997 - val_loss: 0.5153
# Epoch 13/20
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4730 - val_loss: 0.4760
# Epoch 14/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4620 - val_loss: 0.4771
# Epoch 15/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4621 - val_loss: 0.4795
# Epoch 16/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4581 - val_loss: 0.4833
# Epoch 17/20
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4586 - val_loss: 0.4611
# Epoch 18/20
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4599 - val_loss: 0.4648
# Epoch 19/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4639 - val_loss: 0.4632
# Epoch 20/20
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4626 - val_loss: 0.4694

# %%
plt.figure(figsize=(13,8))
plt.plot(history.history['loss'], label="loss")
plt.plot(history.history['val_loss'], label="val_loss")
plt.legend()
plt.show()

# %%
y_hat_test = model.predict(X_test)

plt.scatter(X_test, y_test,label = 'ground_truth', alpha=0.1)
plt.scatter(X_test, y_hat_test,label = 'predicted', alpha=0.5)

plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Build an MLP to classify MNIST images
#
# Every MNIST data point has two parts: an image of a handwritten digit and a corresponding label. We’ll call the images “x” and the labels “y”. Both the training set and test set contain images and their corresponding labels; for example, the training images are mnist.train.images and the training labels are mnist.train.labels.

# %%
# Load dataset
from tensorflow.keras.datasets import mnist

# the data, shuffled and split between a train and test sets 
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
# Reshape the image from 3d to 2d (nb_items, other dime)
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(X_test.shape[0], 784)

# %%
# Normalize the data (input between 0 and 1)
X_train = X_train/255
X_test = X_test/255

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
# One hot encode the label
from sklearn.preprocessing import OneHotEncoder

# Create an instance of the OneHotEncoder
encoder = OneHotEncoder()

# Fit and transform the training labels
y_train_encoded = encoder.fit_transform(y_train.reshape(-1, 1))

# Transform the test labels
y_test_encoded = encoder.transform(y_test.reshape(-1, 1))
y_test_encoded = y_test_encoded.toarray()

# %%
# Buid MLP model
# You can use the following function
def build_MLP(input_shape, activation, layers, nb_class):
    input = Input(shape=(input_shape,), name='input')

    for i, hidden_size in enumerate(layers):
        if i == 0:
            x = Dense(input_shape=(input_shape,), units=hidden_size, activation=activation, name='layer_'+str(i))(input)
        else:
            x = Dense(units=hidden_size, activation=activation, name='layer_'+str(i))(x)

    output = Dense(nb_class, activation='softmax', name='output')(x)
    model = Model(input, output, name = 'mnist_classifier')
    model.summary()
    return model


input_shape = 784
activation = 'relu'
layers = [64, 32, 16]
nb_class = 10


model = build_MLP(input_shape, activation, layers, nb_class)
# Out:
# Model: "mnist_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 784)]             0
#
#  layer_0 (Dense)             (None, 64)                50240
#
#  layer_1 (Dense)             (None, 32)                2080
#
#  layer_2 (Dense)             (None, 16)                528
#
#  output (Dense)              (None, 10)                170
#
# =================================================================
# Total params: 53,018
# Trainable params: 53,018
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile and fit the model
callbacks_list = [EarlyStopping(monitor='val_accuracy', min_delta=0.005, patience=20,
                                verbose=2, mode='min', restore_best_weights=True)
                 ]

model.compile(loss='categorical_crossentropy', metrics=["accuracy"], optimizer='adam')
y_train_encoded = y_train_encoded.toarray()

history = model.fit(X_train, y_train_encoded, validation_split=0.1, callbacks=callbacks_list, batch_size=32, epochs=20)
# Out:
# Epoch 1/20
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.3528 - accuracy: 0.8957 - val_loss: 0.1426 - val_accuracy: 0.9573
# Epoch 2/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1480 - accuracy: 0.9555 - val_loss: 0.1396 - val_accuracy: 0.9580
# Epoch 3/20
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1093 - accuracy: 0.9664 - val_loss: 0.0971 - val_accuracy: 0.9685
# Epoch 4/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0866 - accuracy: 0.9738 - val_loss: 0.0984 - val_accuracy: 0.9715
# Epoch 5/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0727 - accuracy: 0.9768 - val_loss: 0.0869 - val_accuracy: 0.9758
# Epoch 6/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0604 - accuracy: 0.9813 - val_loss: 0.0974 - val_accuracy: 0.9712
# Epoch 7/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0526 - accuracy: 0.9830 - val_loss: 0.0906 - val_accuracy: 0.9755
# Epoch 8/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0470 - accuracy: 0.9848 - val_loss: 0.0836 - val_accuracy: 0.9778
# Epoch 9/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0402 - accuracy: 0.9865 - val_loss: 0.1106 - val_accuracy: 0.9722
# Epoch 10/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0359 - accuracy: 0.9883 - val_loss: 0.0963 - val_accuracy: 0.9750
# Epoch 11/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0308 - accuracy: 0.9895 - val_loss: 0.1088 - val_accuracy: 0.9748
# Epoch 12/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0288 - accuracy: 0.9903 - val_loss: 0.1218 - val_accuracy: 0.9723
# Epoch 13/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0274 - accuracy: 0.9909 - val_loss: 0.1111 - val_accuracy: 0.9728
# Epoch 14/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0233 - accuracy: 0.9924 - val_loss: 0.1137 - val_accuracy: 0.9767
# Epoch 15/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0229 - accuracy: 0.9919 - val_loss: 0.1389 - val_accuracy: 0.9720
# Epoch 16/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.1427 - val_accuracy: 0.9687
# Epoch 17/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0198 - accuracy: 0.9930 - val_loss: 0.1450 - val_accuracy: 0.9743
# Epoch 18/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.1324 - val_accuracy: 0.9778
# Epoch 19/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.1376 - val_accuracy: 0.9755
# Epoch 20/20
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.1337 - val_accuracy: 0.9755

# %%
y_train.shape
# Out:
# (60000,)

# %%
# Print history keys
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Babysit your model
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(26,8))

ax1.plot(history.history['loss'], label="loss")
ax1.plot(history.history['val_loss'], label="val_loss")
ax1.legend()
ax2.plot(history.history['accuracy'], label="accuracy")
ax2.plot(history.history['val_accuracy'], label="val_accuracy")
ax2.legend()
plt.show()

# %%
# Evaluate the model
score = model.evaluate(X_test, y_test_encoded)
print('Test loss:', score[0])
print('Test accuracy', score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1386 - accuracy: 0.9731
# Test loss: 0.13860878348350525
# Test accuracy 0.9731000065803528

# %%
# Modify the network in order to obtain better accuracy (better than 0.96)
