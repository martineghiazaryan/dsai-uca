# %% [markdown]
# # Time series prediction with LSTM (student notebook)
#
# Neural networks like Long Short-Term Memory (LSTM) recurrent neural networks are able to almost seamlessly model problems with multiple input variables.
#
# This is a great benefit in time series forecasting, where classical linear methods can be difficult to adapt to multivariate or multiple input forecasting problems.
#
# In this lab, you will discover how you can develop an LSTM model for multivariate time series forecasting with the Keras deep learning library.

# %%
"""
(Practical tip) Table of contents can be compiled directly in jupyter notebooks using the following code:
I set an exception: if the package is in your installation you can import it otherwise you download it 
then import it.
"""
try:
    from jyquickhelper import add_notebook_menu 
except:
    # !pip install jyquickhelper
    from jyquickhelper import add_notebook_menu
    
"""
Output Table of contents to navigate easily in the notebook. 
For interested readers, the package also includes Ipython magic commands to go back to this cell
wherever you are in the notebook to look for cells faster
"""
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## Imports

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
import matplotlib.pyplot as plt

import math
import numpy as np 
import pandas as pd

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Embedding, Flatten, LSTM, Bidirectional, AveragePooling1D, RepeatVector
from tensorflow.keras import utils

# %% [markdown]
# ## LSTM network for uni-variate time series
#
# LSTM can be used to model univariate time series forecasting problems.
#
# These problems consist of a single set of observations and a model is needed to learn from the past set of observations in order to forecast the next value in the sequence.
#
# We will demonstrate a number of variations of the LSTM model for univariate time series forecasting.
#
# Be careful not to draw hasty conclusions about the relative performance of the models. The number of layers or neurons are highly variable between models.

# %% [markdown]
# ### Data preparation
#
# #### A first example
#
# Consider a given univariate sequence: `[10, 20, 30, 40, 50, 60, 70, 80, 90]`
#
# We can divide the sequence into multiple input/output patterns called samples, where three time steps are used as input and one time step is used as output for the one-step prediction that is being learned.
#
# `X,				y
# 10, 20, 30		40
# 20, 30, 40		50
# 30, 40, 50		60
# ...`
#
# The `series_to_supervised()` function below implements this behavior and will split a given univariate sequence into multiple samples where each sample has a specified number of time steps (`n_in, by default 3`) and the output has also a specified number of time steps (`n_out, by default 1`).
#
# By default, the data to predict is the last columns.

# %%
def series_to_supervised(data, n_in=3, n_out=1, output=None, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    output =  [data.columns[-1]] if output is None else output
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols += [df.shift(i)]
        names += [('%s(t-%d)' % (j, i)) for j in data.columns]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols += [df[output].shift(-i)]
        if i == 0:
            names += [('%s(t)' % (j)) for j in output]
        else:
            names += [('%s(t+%d)' % (j, i)) for j in output]
    
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * create the time series mentioned in the first exemple.
# </font>

# %%
my_time_series = [10, 20, 30, 40, 50, 60, 70, 80, 90]
my_time_series = pd.DataFrame(data=my_time_series)
my_time_series
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60
# 6  70
# 7  80
# 8  90

# %%
data = series_to_supervised(my_time_series, n_in=3, n_out=1)
data.head()
# Out:
#    0(t-3)  0(t-2)  0(t-1)  0(t)
# 3    10.0    20.0    30.0    40
# 4    20.0    30.0    40.0    50
# 5    30.0    40.0    50.0    60
# 6    40.0    50.0    60.0    70
# 7    50.0    60.0    70.0    80

# %% [markdown]
# <font color='blue'>
#     <bold>Head of the previous dataset</bold>
#
# `	0(t-3)	0(t-2)	0(t-1)	0(t)
# 3	0.0	10.0	20.0	30
# 4	10.0	20.0	30.0	40
# 5	20.0	30.0	40.0	50
# 6	30.0	40.0	50.0	60
# 7	40.0	50.0	60.0	70
# `
# </font>

# %% [markdown]
# #### Do the same for a more sophisticated series

# %%
SIZE = 250
time_stamps = range(SIZE)

fct = lambda x: x*math.sin(x)
time_series = pd.DataFrame(data={"data":[fct(x) for x in range(SIZE)]})
n_features = time_series.shape[1] # for univariate time series

# %%
time_series.shape
# Out:
# (250, 1)

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * Plot the time series generated thanks to x --> x*sin(x) with 250 timestamps
# * label x and y axis
# </font>

# %%
plt.figure(figsize=(10,4))
plt.plot(time_stamps, time_series)
plt.xlabel('time stamps')
plt.ylabel('time series')
# Out:
# Text(0, 0.5, 'time series')

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * Using `series_to_supervise` split data into samples with n_in = 6 and n_out = 1
# * Put the result in variable data
# </font>

# %%
n_in = 6
n_out = 1
data = series_to_supervised(time_series, n_in, n_out)
data.head()
# Out:
#     data(t-6)  data(t-5)  data(t-4)  data(t-3)  data(t-2)  data(t-1)   data(t)
# 6    0.000000   0.841471   1.818595   0.423360  -3.027210  -4.794621 -1.676493
# 7    0.841471   1.818595   0.423360  -3.027210  -4.794621  -1.676493  4.598906
# 8    1.818595   0.423360  -3.027210  -4.794621  -1.676493   4.598906  7.914866
# 9    0.423360  -3.027210  -4.794621  -1.676493   4.598906   7.914866  3.709066
# 10  -3.027210  -4.794621  -1.676493   4.598906   7.914866   3.709066 -5.440211

# %% [markdown]
# <font color='blue'>
#     <bold>Head of the previous dataset</bold>
#
# `idx  data(t-6)	 data(t-5)	 data(t-4)	 data(t-3)	 data(t-2)	 data(t-1)	 data(t)
#  6	 0.000000	 0.841471	 1.818595	 0.423360	-3.027210	-4.794621	-1.676493
#  7	 0.841471	 1.818595	 0.423360	-3.027210	-4.794621	-1.676493	 4.598906
#  8	 1.818595	 0.423360	-3.027210	-4.794621	-1.676493	 4.598906	 7.914866
#  9	 0.423360	-3.027210	-4.794621	-1.676493	 4.598906	 7.914866	 3.709066
# 10	-3.027210	-4.794621	-1.676493	 4.598906	 7.914866	 3.709066	-5.440211
# `
# </font>

# %% [markdown]
# Contrary to the approaches used so far, we cannot separate the data into TRAIN, VALID and TEST in a random way, since we are dealing with time series where the order is important.
#
# The TRAIN data will therefore necessarily be at the beginning, then we will find the VALIDATION data and finally the TEST data.
#
# Here are the chosen indices.

# %%
testAndValid = 0.1

SPLIT = int(testAndValid*len(data))
idx_train = len(data)-2*SPLIT
idx_test = len(data)-SPLIT

print("TRAIN=time_series[:"+str(idx_train)+"]")
print("VALID=time_series["+str(idx_train)+":"+str(idx_test)+"]")
print("TEST=time_series["+str(idx_test)+":]")

TRAIN=data[:idx_train]
VAL=data[idx_train:idx_test]
TEST=data[idx_test:]
# Out:
# TRAIN=time_series[:196]
# VALID=time_series[196:220]
# TEST=time_series[220:]

# %%
plt.figure(figsize=(10, 4))
plt.plot(TRAIN['data(t)'], label="train")
plt.plot(VAL['data(t)'], label="val")
plt.plot(TEST['data(t)'], label="test")
plt.legend()
plt.xlabel("time stamps");
plt.ylabel("time series");

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * complete the code for preprocessing your train/validation/test datasets.
# </font>

# %%
# split into input and outputs
train_X, train_y = TRAIN.values[:, :-n_out], TRAIN.values[:, -n_out]
val_X, val_y = VAL.values[:, :-n_out], VAL.values[:, -n_out]
test_X, test_y =  TEST.values[:, :-n_out], TEST.values[:, -n_out]

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((-1, n_in, n_features))
val_X = val_X.reshape((-1, n_in, n_features))
test_X = test_X.reshape((-1, n_in, n_features))


train_X.shape, train_y.shape
# Out:
# ((196, 6, 1), (196,))

# %% [markdown]
# <font color='blue'>
# <bold>
# train_X.shape = (196, 6, 1)
#
# train_y.shape = (196,)
# </font>

# %% [markdown]
# ### Build a first network using LSTM cells
# <br>
# <font color='red'>
# $TO DO - Students$
#
# * Look carefully at the following cell
# * What is the impact of the `return_sequences` parameter of the LSTM cell? (change the value: False or True and observe the shape of the output).
# </font>

# %%
LSTM_SIZE = 16

inputs = Input(shape=(n_in, n_features))
hidden = LSTM(LSTM_SIZE, return_sequences=False, activation='relu')(inputs)
outputs = Dense(n_out, activation='linear')(hidden)
model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 6, 1)]            0
#
#  lstm (LSTM)                 (None, 16)                1152
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * Is it Regression or Classification problem ?
# * Complete the function build_and_fit used to train your RNN model.
# * compile : as usual
# * fit : as usual but...
#     * Be careful, you have to set the shuffle parameter to false in order to take the data in order.
#     * Use the validation set to control the overfitting in the earlystopping callback
# </font>

# %%
def build_and_fit(model, X_train, y_train, X_val, y_val, X_test, y_test, patience=150):
    model.compile(optimizer="Adam", loss='mse', metrics=['mae']) # Fix the loss='mse' and metrics=['mae']. 
    es = EarlyStopping(monitor='val_loss', patience=patience, mode='min', restore_best_weights=True)
    history = model.fit(X_train, y_train, epochs=200, callbacks=[es], validation_data=(X_val, y_val), shuffle=False) # epochs = 200, EarlyStopping, use validation_data
    y_pred = model.predict(X_test)
    
    # plot history
    plt.figure(figsize=(20,8))

    plt.subplot(331)
    plt.plot(history.history['loss'][3:], label='loss')
    plt.plot(history.history['val_loss'][3:], label='val_loss')
    plt.legend()
    
    plt.subplot(332)
    plt.plot(history.history['mae'][3:], label='mae')
    plt.plot(history.history['val_mae'][3:], label='val_mae')
    plt.legend()
    
    plt.subplot(333)
    plt.plot(range(len(y_train)), y_train, label="train")
    plt.plot(range(len(y_train), len(y_train)+len(y_val)), y_val, label="valid")
    plt.plot(range(len(y_train)+len(y_val), len(y_train)+len(y_val)+len(y_pred)), y_test, label="test")
    plt.plot(range(len(y_train)+len(y_val), len(y_train)+len(y_val)+len(y_pred)), y_pred, label="predict")

    plt.legend(loc='center left')
    plt.show()
    
    return model

# %%
model = build_and_fit(model, train_X, train_y, val_X, val_y, test_X, test_y)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 2s 61ms/step - loss: 6664.9932 - mae: 64.7393 - val_loss: 22171.6094 - val_mae: 135.2965
# Epoch 2/200
# 7/7 [==============================] - 0s 9ms/step - loss: 6174.2397 - mae: 62.5712 - val_loss: 20530.1719 - val_mae: 130.8614
# Epoch 3/200
# 7/7 [==============================] - 0s 8ms/step - loss: 5739.2236 - mae: 60.6080 - val_loss: 18728.0059 - val_mae: 125.5009
# Epoch 4/200
# 7/7 [==============================] - 0s 11ms/step - loss: 5350.7236 - mae: 58.7063 - val_loss: 17020.3184 - val_mae: 120.1159
# Epoch 5/200
# 7/7 [==============================] - 0s 16ms/step - loss: 4976.2900 - mae: 56.7080 - val_loss: 15866.1963 - val_mae: 115.9953
# Epoch 6/200
# 7/7 [==============================] - 0s 9ms/step - loss: 4556.0356 - mae: 54.3918 - val_loss: 14292.1221 - val_mae: 110.1209
# Epoch 7/200
# 7/7 [==============================] - 0s 17ms/step - loss: 4047.0930 - mae: 51.4712 - val_loss: 12504.0000 - val_mae: 102.9585
# Epoch 8/200
# 7/7 [==============================] - 0s 9ms/step - loss: 3383.2861 - mae: 47.3655 - val_loss: 10054.2510 - val_mae: 91.2230
# Epoch 9/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2508.7180 - mae: 40.0941 - val_loss: 6306.6929 - val_mae: 71.0004
# Epoch 10/200
# 7/7 [==============================] - 0s 9ms/step - loss: 1481.5295 - mae: 30.6250 - val_loss: 3792.5159 - val_mae: 54.6690
# Epoch 11/200
# 7/7 [==============================] - 0s 13ms/step - loss: 828.5049 - mae: 23.4298 - val_loss: 2606.2834 - val_mae: 43.9309
# Epoch 12/200
# 7/7 [==============================] - 0s 11ms/step - loss: 527.5786 - mae: 17.9017 - val_loss: 1453.1234 - val_mae: 30.6359
# Epoch 13/200
# 7/7 [==============================] - 0s 10ms/step - loss: 307.7746 - mae: 13.0154 - val_loss: 800.2786 - val_mae: 22.8591
# Epoch 14/200
# 7/7 [==============================] - 0s 13ms/step - loss: 167.9109 - mae: 10.0419 - val_loss: 642.9453 - val_mae: 21.0048
# Epoch 15/200
# 7/7 [==============================] - 0s 11ms/step - loss: 146.3756 - mae: 9.1583 - val_loss: 505.7594 - val_mae: 17.0679
# Epoch 16/200
# 7/7 [==============================] - 0s 11ms/step - loss: 107.4582 - mae: 7.7508 - val_loss: 393.7433 - val_mae: 14.7505
# Epoch 17/200
# 7/7 [==============================] - 0s 9ms/step - loss: 87.7163 - mae: 6.8345 - val_loss: 421.0159 - val_mae: 15.9006
# Epoch 18/200
# 7/7 [==============================] - 0s 9ms/step - loss: 73.1670 - mae: 6.3847 - val_loss: 358.2329 - val_mae: 14.9294
# Epoch 19/200
# 7/7 [==============================] - 0s 8ms/step - loss: 63.2551 - mae: 6.0313 - val_loss: 250.0011 - val_mae: 13.0526
# Epoch 20/200
# 7/7 [==============================] - 0s 8ms/step - loss: 58.6695 - mae: 5.7863 - val_loss: 205.2871 - val_mae: 11.4260
# Epoch 21/200
# 7/7 [==============================] - 0s 8ms/step - loss: 52.1456 - mae: 5.5710 - val_loss: 310.6570 - val_mae: 13.0573
# Epoch 22/200
# 7/7 [==============================] - 0s 8ms/step - loss: 44.7590 - mae: 5.0314 - val_loss: 277.2621 - val_mae: 11.2683
# Epoch 23/200
# 7/7 [==============================] - 0s 9ms/step - loss: 39.5613 - mae: 4.7600 - val_loss: 261.6849 - val_mae: 10.8403
# Epoch 24/200
# 7/7 [==============================] - 0s 9ms/step - loss: 35.1910 - mae: 4.5023 - val_loss: 249.9214 - val_mae: 10.8629
# Epoch 25/200
# 7/7 [==============================] - 0s 10ms/step - loss: 33.4743 - mae: 4.4954 - val_loss: 320.3799 - val_mae: 11.7191
# Epoch 26/200
# 7/7 [==============================] - 0s 9ms/step - loss: 31.6445 - mae: 4.3296 - val_loss: 280.6311 - val_mae: 11.2977
# Epoch 27/200
# 7/7 [==============================] - 0s 30ms/step - loss: 32.7434 - mae: 4.3804 - val_loss: 311.4071 - val_mae: 11.4143
# Epoch 28/200
# 7/7 [==============================] - 0s 21ms/step - loss: 32.3665 - mae: 4.4335 - val_loss: 296.1593 - val_mae: 11.5334
# Epoch 29/200
# 7/7 [==============================] - 0s 19ms/step - loss: 28.3749 - mae: 4.0380 - val_loss: 204.5739 - val_mae: 9.8261
# Epoch 30/200
# 7/7 [==============================] - 0s 20ms/step - loss: 28.5940 - mae: 4.0386 - val_loss: 143.2178 - val_mae: 9.7802
# Epoch 31/200
# 7/7 [==============================] - 0s 20ms/step - loss: 26.1189 - mae: 3.8954 - val_loss: 166.3839 - val_mae: 9.3457
# Epoch 32/200
# 7/7 [==============================] - 0s 17ms/step - loss: 25.7153 - mae: 3.9598 - val_loss: 188.0228 - val_mae: 10.0222
# Epoch 33/200
# 7/7 [==============================] - 0s 21ms/step - loss: 24.0413 - mae: 3.7518 - val_loss: 199.4736 - val_mae: 10.3700
# Epoch 34/200
# 7/7 [==============================] - 0s 19ms/step - loss: 22.4290 - mae: 3.5861 - val_loss: 195.6403 - val_mae: 10.2996
# Epoch 35/200
# 7/7 [==============================] - 0s 24ms/step - loss: 21.2342 - mae: 3.5786 - val_loss: 200.7440 - val_mae: 10.4135
# Epoch 36/200
# 7/7 [==============================] - 0s 17ms/step - loss: 20.1854 - mae: 3.4134 - val_loss: 160.0586 - val_mae: 9.5415
# Epoch 37/200
# 7/7 [==============================] - 0s 14ms/step - loss: 19.0932 - mae: 3.3285 - val_loss: 186.6491 - val_mae: 9.9027
# Epoch 38/200
# 7/7 [==============================] - 0s 17ms/step - loss: 18.2473 - mae: 3.2676 - val_loss: 188.1750 - val_mae: 9.9293
# Epoch 39/200
# 7/7 [==============================] - 0s 15ms/step - loss: 17.4244 - mae: 3.1746 - val_loss: 162.7289 - val_mae: 9.4326
# Epoch 40/200
# 7/7 [==============================] - 0s 24ms/step - loss: 16.9147 - mae: 3.0897 - val_loss: 168.9064 - val_mae: 9.5985
# Epoch 41/200
# 7/7 [==============================] - 0s 18ms/step - loss: 16.7033 - mae: 3.0917 - val_loss: 185.1756 - val_mae: 9.5377
# Epoch 42/200
# 7/7 [==============================] - 0s 21ms/step - loss: 16.9000 - mae: 3.1028 - val_loss: 165.1647 - val_mae: 9.3637
# Epoch 43/200
# 7/7 [==============================] - 0s 15ms/step - loss: 17.4997 - mae: 3.1419 - val_loss: 135.8990 - val_mae: 8.6102
# Epoch 44/200
# 7/7 [==============================] - 0s 19ms/step - loss: 18.3224 - mae: 3.2114 - val_loss: 141.1373 - val_mae: 9.0424
# Epoch 45/200
# 7/7 [==============================] - 0s 18ms/step - loss: 16.3583 - mae: 3.1216 - val_loss: 159.2730 - val_mae: 9.1836
# Epoch 46/200
# 7/7 [==============================] - 0s 14ms/step - loss: 16.2085 - mae: 3.0433 - val_loss: 128.9722 - val_mae: 8.6046
# Epoch 47/200
# 7/7 [==============================] - 0s 18ms/step - loss: 14.6397 - mae: 2.9234 - val_loss: 151.8923 - val_mae: 8.9922
# Epoch 48/200
# 7/7 [==============================] - 0s 41ms/step - loss: 14.0943 - mae: 2.8628 - val_loss: 153.5251 - val_mae: 8.9603
# Epoch 49/200
# 7/7 [==============================] - 0s 19ms/step - loss: 13.5638 - mae: 2.8286 - val_loss: 156.6224 - val_mae: 9.1086
# Epoch 50/200
# 7/7 [==============================] - 0s 27ms/step - loss: 13.3429 - mae: 2.7528 - val_loss: 170.1380 - val_mae: 9.2164
# Epoch 51/200
# 7/7 [==============================] - 0s 18ms/step - loss: 12.7794 - mae: 2.7151 - val_loss: 174.2797 - val_mae: 9.2865
# Epoch 52/200
# 7/7 [==============================] - 0s 22ms/step - loss: 13.1804 - mae: 2.7415 - val_loss: 156.4303 - val_mae: 9.0335
# Epoch 53/200
# 7/7 [==============================] - 0s 18ms/step - loss: 12.4639 - mae: 2.7116 - val_loss: 178.7730 - val_mae: 9.2322
# Epoch 54/200
# 7/7 [==============================] - 0s 16ms/step - loss: 12.6958 - mae: 2.7072 - val_loss: 177.1810 - val_mae: 9.2099
# Epoch 55/200
# 7/7 [==============================] - 0s 18ms/step - loss: 11.9544 - mae: 2.6395 - val_loss: 181.9126 - val_mae: 9.1877
# Epoch 56/200
# 7/7 [==============================] - 0s 19ms/step - loss: 11.7666 - mae: 2.5996 - val_loss: 179.3717 - val_mae: 9.1068
# Epoch 57/200
# 7/7 [==============================] - 0s 27ms/step - loss: 11.0295 - mae: 2.5199 - val_loss: 188.6106 - val_mae: 9.1465
# Epoch 58/200
# 7/7 [==============================] - 0s 14ms/step - loss: 10.7717 - mae: 2.4785 - val_loss: 189.2320 - val_mae: 9.1056
# Epoch 59/200
# 7/7 [==============================] - 0s 13ms/step - loss: 10.3061 - mae: 2.4184 - val_loss: 192.2537 - val_mae: 9.0355
# Epoch 60/200
# 7/7 [==============================] - 0s 16ms/step - loss: 10.1781 - mae: 2.4173 - val_loss: 188.1531 - val_mae: 8.9056
# Epoch 61/200
# 7/7 [==============================] - 0s 27ms/step - loss: 10.1025 - mae: 2.3945 - val_loss: 189.4264 - val_mae: 8.8233
# Epoch 62/200
# 7/7 [==============================] - 0s 18ms/step - loss: 10.5806 - mae: 2.4624 - val_loss: 186.8145 - val_mae: 8.7168
# Epoch 63/200
# 7/7 [==============================] - 0s 19ms/step - loss: 10.4378 - mae: 2.4316 - val_loss: 185.1665 - val_mae: 8.6747
# Epoch 64/200
# 7/7 [==============================] - 0s 24ms/step - loss: 11.0852 - mae: 2.4978 - val_loss: 186.9110 - val_mae: 8.6953
# Epoch 65/200
# 7/7 [==============================] - 0s 27ms/step - loss: 9.7169 - mae: 2.3706 - val_loss: 176.7126 - val_mae: 8.6135
# Epoch 66/200
# 7/7 [==============================] - 0s 19ms/step - loss: 8.9254 - mae: 2.2934 - val_loss: 179.2690 - val_mae: 8.3993
# Epoch 67/200
# 7/7 [==============================] - 0s 18ms/step - loss: 8.8974 - mae: 2.2475 - val_loss: 195.1025 - val_mae: 8.4217
# Epoch 68/200
# 7/7 [==============================] - 0s 36ms/step - loss: 8.7465 - mae: 2.2554 - val_loss: 186.8844 - val_mae: 8.3074
# Epoch 69/200
# 7/7 [==============================] - 0s 28ms/step - loss: 8.7847 - mae: 2.2389 - val_loss: 182.6814 - val_mae: 8.1867
# Epoch 70/200
# 7/7 [==============================] - 0s 19ms/step - loss: 8.8992 - mae: 2.2756 - val_loss: 173.9100 - val_mae: 8.0093
# Epoch 71/200
# 7/7 [==============================] - 0s 20ms/step - loss: 9.2966 - mae: 2.3337 - val_loss: 112.6681 - val_mae: 7.1203
# Epoch 72/200
# 7/7 [==============================] - 0s 19ms/step - loss: 8.2697 - mae: 2.2250 - val_loss: 124.6175 - val_mae: 7.0345
# Epoch 73/200
# 7/7 [==============================] - 0s 14ms/step - loss: 8.1678 - mae: 2.1553 - val_loss: 138.0690 - val_mae: 7.2529
# Epoch 74/200
# 7/7 [==============================] - 0s 17ms/step - loss: 7.8145 - mae: 2.1062 - val_loss: 149.2183 - val_mae: 7.4373
# Epoch 75/200
# 7/7 [==============================] - 0s 15ms/step - loss: 7.5185 - mae: 2.0823 - val_loss: 169.2349 - val_mae: 7.6334
# Epoch 76/200
# 7/7 [==============================] - 0s 13ms/step - loss: 7.3377 - mae: 2.0264 - val_loss: 149.8072 - val_mae: 7.3667
# Epoch 77/200
# 7/7 [==============================] - 0s 13ms/step - loss: 7.2064 - mae: 2.0191 - val_loss: 164.2323 - val_mae: 7.5575
# Epoch 78/200
# 7/7 [==============================] - 0s 13ms/step - loss: 7.1025 - mae: 2.0112 - val_loss: 166.9920 - val_mae: 7.5965
# Epoch 79/200
# 7/7 [==============================] - 0s 16ms/step - loss: 7.0320 - mae: 2.0207 - val_loss: 165.9998 - val_mae: 7.6695
# Epoch 80/200
# 7/7 [==============================] - 0s 16ms/step - loss: 7.4307 - mae: 2.0735 - val_loss: 162.8516 - val_mae: 7.6444
# Epoch 81/200
# 7/7 [==============================] - 0s 16ms/step - loss: 7.2943 - mae: 2.0807 - val_loss: 159.5969 - val_mae: 7.6153
# Epoch 82/200
# 7/7 [==============================] - 0s 36ms/step - loss: 7.4620 - mae: 2.1024 - val_loss: 149.4370 - val_mae: 7.4899
# Epoch 83/200
# 7/7 [==============================] - 0s 12ms/step - loss: 7.1243 - mae: 2.0564 - val_loss: 155.6859 - val_mae: 7.5295
# Epoch 84/200
# 7/7 [==============================] - 0s 18ms/step - loss: 7.1732 - mae: 2.0677 - val_loss: 146.2253 - val_mae: 7.4743
# Epoch 85/200
# 7/7 [==============================] - 0s 20ms/step - loss: 6.9908 - mae: 2.0513 - val_loss: 139.7202 - val_mae: 7.2843
# Epoch 86/200
# 7/7 [==============================] - 0s 20ms/step - loss: 6.9241 - mae: 2.0333 - val_loss: 141.3719 - val_mae: 7.3908
# Epoch 87/200
# 7/7 [==============================] - 0s 27ms/step - loss: 6.5783 - mae: 1.9861 - val_loss: 131.0522 - val_mae: 7.1682
# Epoch 88/200
# 7/7 [==============================] - 0s 18ms/step - loss: 6.2573 - mae: 1.9277 - val_loss: 139.7024 - val_mae: 7.3674
# Epoch 89/200
# 7/7 [==============================] - 0s 15ms/step - loss: 5.8856 - mae: 1.8645 - val_loss: 140.7125 - val_mae: 7.3212
# Epoch 90/200
# 7/7 [==============================] - 0s 16ms/step - loss: 5.7263 - mae: 1.8296 - val_loss: 130.3408 - val_mae: 7.2398
# Epoch 91/200
# 7/7 [==============================] - 0s 27ms/step - loss: 5.5418 - mae: 1.8015 - val_loss: 128.6538 - val_mae: 7.1335
# Epoch 92/200
# 7/7 [==============================] - 0s 21ms/step - loss: 5.5005 - mae: 1.7989 - val_loss: 110.0060 - val_mae: 6.9172
# Epoch 93/200
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6099 - mae: 1.8372 - val_loss: 111.2845 - val_mae: 6.8849
# Epoch 94/200
# 7/7 [==============================] - 0s 20ms/step - loss: 6.1001 - mae: 1.8982 - val_loss: 139.7605 - val_mae: 7.3366
# Epoch 95/200
# 7/7 [==============================] - 0s 31ms/step - loss: 5.9055 - mae: 1.9274 - val_loss: 109.6705 - val_mae: 6.8849
# Epoch 96/200
# 7/7 [==============================] - 0s 20ms/step - loss: 5.7196 - mae: 1.8723 - val_loss: 119.2072 - val_mae: 7.0905
# Epoch 97/200
# 7/7 [==============================] - 0s 18ms/step - loss: 5.3392 - mae: 1.7786 - val_loss: 122.1704 - val_mae: 7.0622
# Epoch 98/200
# 7/7 [==============================] - 0s 18ms/step - loss: 5.1577 - mae: 1.7434 - val_loss: 107.6162 - val_mae: 6.9155
# Epoch 99/200
# 7/7 [==============================] - 0s 19ms/step - loss: 5.0338 - mae: 1.7310 - val_loss: 97.5417 - val_mae: 6.6325
# Epoch 100/200
# 7/7 [==============================] - 0s 21ms/step - loss: 4.8796 - mae: 1.6982 - val_loss: 119.5150 - val_mae: 7.0758
# Epoch 101/200
# 7/7 [==============================] - 0s 19ms/step - loss: 4.7346 - mae: 1.6754 - val_loss: 109.1147 - val_mae: 6.9221
# Epoch 102/200
# 7/7 [==============================] - 0s 26ms/step - loss: 4.5658 - mae: 1.6369 - val_loss: 109.3090 - val_mae: 6.9291
# Epoch 103/200
# 7/7 [==============================] - 0s 27ms/step - loss: 4.4695 - mae: 1.6286 - val_loss: 99.5319 - val_mae: 6.7753
# Epoch 104/200
# 7/7 [==============================] - 0s 25ms/step - loss: 4.3910 - mae: 1.5977 - val_loss: 109.3829 - val_mae: 6.8895
# Epoch 105/200
# 7/7 [==============================] - 0s 28ms/step - loss: 4.3957 - mae: 1.6211 - val_loss: 90.1311 - val_mae: 6.5576
# Epoch 106/200
# 7/7 [==============================] - 0s 18ms/step - loss: 4.3290 - mae: 1.5908 - val_loss: 114.0931 - val_mae: 6.9410
# Epoch 107/200
# 7/7 [==============================] - 0s 21ms/step - loss: 4.2392 - mae: 1.5773 - val_loss: 85.9307 - val_mae: 6.5705
# Epoch 108/200
# 7/7 [==============================] - 0s 17ms/step - loss: 4.2748 - mae: 1.5886 - val_loss: 68.2382 - val_mae: 6.1234
# Epoch 109/200
# 7/7 [==============================] - 0s 19ms/step - loss: 4.2904 - mae: 1.5893 - val_loss: 70.3527 - val_mae: 6.2090
# Epoch 110/200
# 7/7 [==============================] - 0s 18ms/step - loss: 4.4839 - mae: 1.6249 - val_loss: 74.0019 - val_mae: 6.2863
# Epoch 111/200
# 7/7 [==============================] - 0s 18ms/step - loss: 4.5577 - mae: 1.6513 - val_loss: 81.8181 - val_mae: 6.4202
# Epoch 112/200
# 7/7 [==============================] - 0s 17ms/step - loss: 4.9152 - mae: 1.7030 - val_loss: 83.1914 - val_mae: 6.5011
# Epoch 113/200
# 7/7 [==============================] - 0s 17ms/step - loss: 5.0717 - mae: 1.7766 - val_loss: 68.0800 - val_mae: 6.0803
# Epoch 114/200
# 7/7 [==============================] - 0s 16ms/step - loss: 5.3392 - mae: 1.7817 - val_loss: 77.5500 - val_mae: 6.3449
# Epoch 115/200
# 7/7 [==============================] - 0s 21ms/step - loss: 4.8404 - mae: 1.6920 - val_loss: 61.1017 - val_mae: 5.9880
# Epoch 116/200
# 7/7 [==============================] - 0s 28ms/step - loss: 5.1904 - mae: 1.7273 - val_loss: 53.8951 - val_mae: 5.7403
# Epoch 117/200
# 7/7 [==============================] - 0s 22ms/step - loss: 4.5166 - mae: 1.6509 - val_loss: 54.6333 - val_mae: 5.7311
# Epoch 118/200
# 7/7 [==============================] - 0s 31ms/step - loss: 4.2595 - mae: 1.6105 - val_loss: 49.1348 - val_mae: 5.6944
# Epoch 119/200
# 7/7 [==============================] - 0s 18ms/step - loss: 4.0109 - mae: 1.5104 - val_loss: 58.5537 - val_mae: 5.7886
# Epoch 120/200
# 7/7 [==============================] - 0s 17ms/step - loss: 3.8510 - mae: 1.4898 - val_loss: 54.9183 - val_mae: 5.8810
# Epoch 121/200
# 7/7 [==============================] - 0s 24ms/step - loss: 3.6521 - mae: 1.4274 - val_loss: 60.6317 - val_mae: 5.9039
# Epoch 122/200
# 7/7 [==============================] - 0s 21ms/step - loss: 3.6271 - mae: 1.4869 - val_loss: 46.5210 - val_mae: 5.5208
# Epoch 123/200
# 7/7 [==============================] - 0s 29ms/step - loss: 3.5141 - mae: 1.4318 - val_loss: 61.0903 - val_mae: 5.8549
# Epoch 124/200
# 7/7 [==============================] - 0s 20ms/step - loss: 3.5049 - mae: 1.4462 - val_loss: 66.0680 - val_mae: 6.0846
# Epoch 125/200
# 7/7 [==============================] - 0s 26ms/step - loss: 3.2710 - mae: 1.3466 - val_loss: 69.4199 - val_mae: 6.0147
# Epoch 126/200
# 7/7 [==============================] - 0s 23ms/step - loss: 3.2186 - mae: 1.3789 - val_loss: 46.8841 - val_mae: 5.5374
# Epoch 127/200
# 7/7 [==============================] - 0s 19ms/step - loss: 3.2086 - mae: 1.3525 - val_loss: 58.8719 - val_mae: 5.7839
# Epoch 128/200
# 7/7 [==============================] - 0s 26ms/step - loss: 3.1634 - mae: 1.3722 - val_loss: 61.7357 - val_mae: 5.9017
# Epoch 129/200
# 7/7 [==============================] - 0s 25ms/step - loss: 3.0788 - mae: 1.2995 - val_loss: 58.5333 - val_mae: 5.7733
# Epoch 130/200
# 7/7 [==============================] - 0s 18ms/step - loss: 3.0700 - mae: 1.3458 - val_loss: 44.7341 - val_mae: 5.3986
# Epoch 131/200
# 7/7 [==============================] - 0s 26ms/step - loss: 3.0688 - mae: 1.3196 - val_loss: 53.0585 - val_mae: 5.6105
# Epoch 132/200
# 7/7 [==============================] - 0s 16ms/step - loss: 3.1339 - mae: 1.3765 - val_loss: 54.7538 - val_mae: 5.6949
# Epoch 133/200
# 7/7 [==============================] - 0s 33ms/step - loss: 3.2124 - mae: 1.3714 - val_loss: 50.8582 - val_mae: 5.5614
# Epoch 134/200
# 7/7 [==============================] - 0s 21ms/step - loss: 3.5183 - mae: 1.4704 - val_loss: 40.6212 - val_mae: 5.1605
# Epoch 135/200
# 7/7 [==============================] - 0s 21ms/step - loss: 3.7679 - mae: 1.4877 - val_loss: 48.6808 - val_mae: 5.4457
# Epoch 136/200
# 7/7 [==============================] - 0s 17ms/step - loss: 4.2382 - mae: 1.5702 - val_loss: 48.5075 - val_mae: 5.5292
# Epoch 137/200
# 7/7 [==============================] - 0s 17ms/step - loss: 4.4424 - mae: 1.6173 - val_loss: 47.5121 - val_mae: 5.3466
# Epoch 138/200
# 7/7 [==============================] - 0s 15ms/step - loss: 5.2489 - mae: 1.7204 - val_loss: 39.1192 - val_mae: 5.1290
# Epoch 139/200
# 7/7 [==============================] - 0s 21ms/step - loss: 4.9758 - mae: 1.6360 - val_loss: 43.8176 - val_mae: 5.1583
# Epoch 140/200
# 7/7 [==============================] - 0s 29ms/step - loss: 5.4801 - mae: 1.6668 - val_loss: 50.6427 - val_mae: 5.4399
# Epoch 141/200
# 7/7 [==============================] - 0s 26ms/step - loss: 4.0438 - mae: 1.5927 - val_loss: 39.2037 - val_mae: 5.0434
# Epoch 142/200
# 7/7 [==============================] - 0s 14ms/step - loss: 4.1480 - mae: 1.6426 - val_loss: 40.8294 - val_mae: 5.1679
# Epoch 143/200
# 7/7 [==============================] - 0s 35ms/step - loss: 4.3587 - mae: 1.5900 - val_loss: 47.5131 - val_mae: 5.3035
# Epoch 144/200
# 7/7 [==============================] - 0s 21ms/step - loss: 4.2372 - mae: 1.5952 - val_loss: 58.9433 - val_mae: 5.6324
# Epoch 145/200
# 7/7 [==============================] - 0s 22ms/step - loss: 3.9855 - mae: 1.5838 - val_loss: 48.0605 - val_mae: 5.4182
# Epoch 146/200
# 7/7 [==============================] - 0s 20ms/step - loss: 4.1111 - mae: 1.6234 - val_loss: 43.2665 - val_mae: 5.0790
# Epoch 147/200
# 7/7 [==============================] - 0s 20ms/step - loss: 3.5501 - mae: 1.5154 - val_loss: 41.4162 - val_mae: 5.0908
# Epoch 148/200
# 7/7 [==============================] - 0s 33ms/step - loss: 3.2899 - mae: 1.4229 - val_loss: 46.6256 - val_mae: 5.3111
# Epoch 149/200
# 7/7 [==============================] - 0s 20ms/step - loss: 2.9301 - mae: 1.3451 - val_loss: 40.9600 - val_mae: 5.0446
# Epoch 150/200
# 7/7 [==============================] - 0s 23ms/step - loss: 2.6529 - mae: 1.2526 - val_loss: 45.2031 - val_mae: 5.2363
# Epoch 151/200
# 7/7 [==============================] - 0s 19ms/step - loss: 2.4339 - mae: 1.1766 - val_loss: 46.5490 - val_mae: 5.3372
# Epoch 152/200
# 7/7 [==============================] - 0s 19ms/step - loss: 2.2954 - mae: 1.1406 - val_loss: 48.7441 - val_mae: 5.3909
# Epoch 153/200
# 7/7 [==============================] - 0s 19ms/step - loss: 2.2334 - mae: 1.1154 - val_loss: 46.3978 - val_mae: 5.3339
# Epoch 154/200
# 7/7 [==============================] - 0s 18ms/step - loss: 2.1682 - mae: 1.0893 - val_loss: 48.6423 - val_mae: 5.3708
# Epoch 155/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.1325 - mae: 1.0791 - val_loss: 47.2881 - val_mae: 5.3275
# Epoch 156/200
# 7/7 [==============================] - 0s 13ms/step - loss: 2.0841 - mae: 1.0625 - val_loss: 47.1220 - val_mae: 5.3003
# Epoch 157/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0563 - mae: 1.0519 - val_loss: 45.0376 - val_mae: 5.2359
# Epoch 158/200
# 7/7 [==============================] - 0s 20ms/step - loss: 2.0223 - mae: 1.0452 - val_loss: 45.7185 - val_mae: 5.2291
# Epoch 159/200
# 7/7 [==============================] - 0s 17ms/step - loss: 2.0222 - mae: 1.0456 - val_loss: 43.3390 - val_mae: 5.1620
# Epoch 160/200
# 7/7 [==============================] - 0s 23ms/step - loss: 2.0484 - mae: 1.0601 - val_loss: 45.0514 - val_mae: 5.1806
# Epoch 161/200
# 7/7 [==============================] - 0s 20ms/step - loss: 2.2101 - mae: 1.0851 - val_loss: 40.5129 - val_mae: 5.0390
# Epoch 162/200
# 7/7 [==============================] - 0s 37ms/step - loss: 2.5445 - mae: 1.1751 - val_loss: 43.3176 - val_mae: 5.0660
# Epoch 163/200
# 7/7 [==============================] - 0s 37ms/step - loss: 3.1032 - mae: 1.2498 - val_loss: 40.4831 - val_mae: 4.9321
# Epoch 164/200
# 7/7 [==============================] - 0s 25ms/step - loss: 2.7966 - mae: 1.2729 - val_loss: 36.6680 - val_mae: 4.7768
# Epoch 165/200
# 7/7 [==============================] - 0s 19ms/step - loss: 3.1439 - mae: 1.3338 - val_loss: 40.7217 - val_mae: 4.9032
# Epoch 166/200
# 7/7 [==============================] - 0s 21ms/step - loss: 3.5052 - mae: 1.4219 - val_loss: 36.2222 - val_mae: 4.6131
# Epoch 167/200
# 7/7 [==============================] - 0s 18ms/step - loss: 4.5842 - mae: 1.5911 - val_loss: 36.1075 - val_mae: 4.6163
# Epoch 168/200
# 7/7 [==============================] - 0s 18ms/step - loss: 5.1621 - mae: 1.6087 - val_loss: 46.4728 - val_mae: 4.8972
# Epoch 169/200
# 7/7 [==============================] - 0s 20ms/step - loss: 4.3644 - mae: 1.5755 - val_loss: 44.0605 - val_mae: 5.0571
# Epoch 170/200
# 7/7 [==============================] - 0s 22ms/step - loss: 3.6094 - mae: 1.4663 - val_loss: 57.7114 - val_mae: 5.3867
# Epoch 171/200
# 7/7 [==============================] - 0s 16ms/step - loss: 3.9478 - mae: 1.4966 - val_loss: 40.7981 - val_mae: 4.9111
# Epoch 172/200
# 7/7 [==============================] - 0s 13ms/step - loss: 3.8612 - mae: 1.4829 - val_loss: 37.5971 - val_mae: 4.6175
# Epoch 173/200
# 7/7 [==============================] - 0s 28ms/step - loss: 3.7065 - mae: 1.4183 - val_loss: 38.0186 - val_mae: 4.7056
# Epoch 174/200
# 7/7 [==============================] - 0s 21ms/step - loss: 3.1859 - mae: 1.3396 - val_loss: 40.1941 - val_mae: 4.8040
# Epoch 175/200
# 7/7 [==============================] - 0s 21ms/step - loss: 3.0058 - mae: 1.3096 - val_loss: 44.4505 - val_mae: 4.9937
# Epoch 176/200
# 7/7 [==============================] - 0s 19ms/step - loss: 2.5481 - mae: 1.2916 - val_loss: 50.0064 - val_mae: 5.0781
# Epoch 177/200
# 7/7 [==============================] - 0s 20ms/step - loss: 2.4318 - mae: 1.2160 - val_loss: 45.0984 - val_mae: 5.0508
# Epoch 178/200
# 7/7 [==============================] - 0s 13ms/step - loss: 2.4093 - mae: 1.2526 - val_loss: 47.3267 - val_mae: 5.0459
# Epoch 179/200
# 7/7 [==============================] - 0s 18ms/step - loss: 2.6781 - mae: 1.2774 - val_loss: 43.0372 - val_mae: 4.9012
# Epoch 180/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.6333 - mae: 1.2968 - val_loss: 50.6144 - val_mae: 5.1956
# Epoch 181/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.8396 - mae: 1.3378 - val_loss: 54.3980 - val_mae: 5.2405
# Epoch 182/200
# 7/7 [==============================] - 0s 26ms/step - loss: 2.6387 - mae: 1.2846 - val_loss: 38.6359 - val_mae: 4.7855
# Epoch 183/200
# 7/7 [==============================] - 0s 25ms/step - loss: 2.6516 - mae: 1.3015 - val_loss: 40.0115 - val_mae: 4.6238
# Epoch 184/200
# 7/7 [==============================] - 0s 19ms/step - loss: 2.6731 - mae: 1.2365 - val_loss: 31.3367 - val_mae: 4.6526
# Epoch 185/200
# 7/7 [==============================] - 0s 19ms/step - loss: 8.4564 - mae: 1.8778 - val_loss: 36.9939 - val_mae: 4.3045
# Epoch 186/200
# 7/7 [==============================] - 0s 29ms/step - loss: 7.8359 - mae: 2.0930 - val_loss: 48.4542 - val_mae: 4.7660
# Epoch 187/200
# 7/7 [==============================] - 0s 30ms/step - loss: 6.8846 - mae: 1.9584 - val_loss: 57.5140 - val_mae: 5.7975
# Epoch 188/200
# 7/7 [==============================] - 0s 45ms/step - loss: 5.7968 - mae: 1.7031 - val_loss: 39.8809 - val_mae: 4.5471
# Epoch 189/200
# 7/7 [==============================] - 0s 29ms/step - loss: 4.2657 - mae: 1.4751 - val_loss: 34.4349 - val_mae: 4.6634
# Epoch 190/200
# 7/7 [==============================] - 0s 31ms/step - loss: 3.1464 - mae: 1.3415 - val_loss: 30.1713 - val_mae: 4.4365
# Epoch 191/200
# 7/7 [==============================] - 0s 20ms/step - loss: 4.3060 - mae: 1.4745 - val_loss: 27.7969 - val_mae: 4.3941
# Epoch 192/200
# 7/7 [==============================] - 0s 19ms/step - loss: 7.2467 - mae: 1.8944 - val_loss: 44.9737 - val_mae: 5.3812
# Epoch 193/200
# 7/7 [==============================] - 0s 12ms/step - loss: 5.8977 - mae: 1.6747 - val_loss: 99.8117 - val_mae: 6.9422
# Epoch 194/200
# 7/7 [==============================] - 0s 18ms/step - loss: 6.7176 - mae: 1.7727 - val_loss: 95.7997 - val_mae: 6.7152
# Epoch 195/200
# 7/7 [==============================] - 0s 25ms/step - loss: 3.9052 - mae: 1.4953 - val_loss: 73.4475 - val_mae: 6.3428
# Epoch 196/200
# 7/7 [==============================] - 0s 25ms/step - loss: 5.3886 - mae: 1.6840 - val_loss: 59.5693 - val_mae: 5.8630
# Epoch 197/200
# 7/7 [==============================] - 0s 14ms/step - loss: 4.8169 - mae: 1.4950 - val_loss: 66.6672 - val_mae: 5.9789
# Epoch 198/200
# 7/7 [==============================] - 0s 13ms/step - loss: 3.4429 - mae: 1.3714 - val_loss: 53.5782 - val_mae: 5.6541
# Epoch 199/200
# 7/7 [==============================] - 0s 26ms/step - loss: 2.7052 - mae: 1.2390 - val_loss: 70.6817 - val_mae: 5.9163
# Epoch 200/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.5488 - mae: 1.1941 - val_loss: 48.3531 - val_mae: 5.3491
# 1/1 [==============================] - 1s 512ms/step

# %% [markdown]
# ### Stacked Bi-LSTM
#
# In order to improve the performance of the model, it's possible to:
# - stack LSTM with `return_sequence=True` for all levels except the last one where `return_sequence=False`
# - use Bi-LSTM

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * Build a model stacking 3 BI-LSTM layers
# </font>

# %%
inputs = Input(shape=(n_in, n_features))
hidden1 = Bidirectional(LSTM(LSTM_SIZE, return_sequences=True, activation='relu'))(inputs)
hidden2 = Bidirectional(LSTM(LSTM_SIZE, return_sequences=True, activation='relu'))(hidden1)
hidden3 = Bidirectional(LSTM(LSTM_SIZE, return_sequences=False,activation='relu'))(hidden2)
outputs = Dense(n_out, activation='linear')(hidden3)
model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 6, 1)]            0
#
#  bidirectional_3 (Bidirectio  (None, 6, 32)            2304
#  nal)
#
#  bidirectional_4 (Bidirectio  (None, 6, 32)            6272
#  nal)
#
#  bidirectional_5 (Bidirectio  (None, 32)               6272
#  nal)
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 14,881
# Trainable params: 14,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = build_and_fit(model, train_X, train_y, val_X, val_y, test_X, test_y)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 9s 187ms/step - loss: 6957.7681 - mae: 65.7765 - val_loss: 23688.3262 - val_mae: 137.6312
# Epoch 2/200
# 7/7 [==============================] - 0s 23ms/step - loss: 6247.9023 - mae: 62.1854 - val_loss: 21460.7656 - val_mae: 130.7147
# Epoch 3/200
# 7/7 [==============================] - 0s 26ms/step - loss: 5757.2090 - mae: 59.6807 - val_loss: 19002.1895 - val_mae: 122.8782
# Epoch 4/200
# 7/7 [==============================] - 0s 24ms/step - loss: 5107.0088 - mae: 56.1493 - val_loss: 16456.8691 - val_mae: 113.8209
# Epoch 5/200
# 7/7 [==============================] - 0s 24ms/step - loss: 4284.6260 - mae: 50.7915 - val_loss: 13210.1592 - val_mae: 97.1058
# Epoch 6/200
# 7/7 [==============================] - 0s 28ms/step - loss: 3262.3413 - mae: 42.9870 - val_loss: 8935.4502 - val_mae: 72.1506
# Epoch 7/200
# 7/7 [==============================] - 0s 24ms/step - loss: 1939.3129 - mae: 32.4899 - val_loss: 4578.5820 - val_mae: 52.2394
# Epoch 8/200
# 7/7 [==============================] - 0s 26ms/step - loss: 719.8055 - mae: 20.6777 - val_loss: 1712.1464 - val_mae: 32.5182
# Epoch 9/200
# 7/7 [==============================] - 0s 24ms/step - loss: 340.5672 - mae: 14.1622 - val_loss: 1241.2808 - val_mae: 28.8447
# Epoch 10/200
# 7/7 [==============================] - 0s 24ms/step - loss: 435.5161 - mae: 15.3114 - val_loss: 782.9500 - val_mae: 22.2820
# Epoch 11/200
# 7/7 [==============================] - 0s 26ms/step - loss: 310.7963 - mae: 12.4765 - val_loss: 487.3144 - val_mae: 16.2570
# Epoch 12/200
# 7/7 [==============================] - 0s 25ms/step - loss: 275.5905 - mae: 11.6030 - val_loss: 930.0818 - val_mae: 24.5220
# Epoch 13/200
# 7/7 [==============================] - 0s 22ms/step - loss: 172.3810 - mae: 9.7642 - val_loss: 565.0574 - val_mae: 19.4593
# Epoch 14/200
# 7/7 [==============================] - 0s 23ms/step - loss: 111.9042 - mae: 8.1807 - val_loss: 350.0061 - val_mae: 15.8247
# Epoch 15/200
# 7/7 [==============================] - 0s 25ms/step - loss: 76.2573 - mae: 6.5210 - val_loss: 356.2920 - val_mae: 14.7303
# Epoch 16/200
# 7/7 [==============================] - 0s 22ms/step - loss: 54.8529 - mae: 5.6700 - val_loss: 238.9988 - val_mae: 12.8532
# Epoch 17/200
# 7/7 [==============================] - 0s 25ms/step - loss: 48.0158 - mae: 5.2391 - val_loss: 213.5628 - val_mae: 11.8858
# Epoch 18/200
# 7/7 [==============================] - 0s 22ms/step - loss: 41.7315 - mae: 4.8972 - val_loss: 253.2227 - val_mae: 12.9796
# Epoch 19/200
# 7/7 [==============================] - 0s 21ms/step - loss: 34.6646 - mae: 4.4834 - val_loss: 193.7876 - val_mae: 11.1657
# Epoch 20/200
# 7/7 [==============================] - 0s 21ms/step - loss: 31.3689 - mae: 4.1161 - val_loss: 164.0790 - val_mae: 10.0993
# Epoch 21/200
# 7/7 [==============================] - 0s 19ms/step - loss: 37.6885 - mae: 4.5332 - val_loss: 238.0963 - val_mae: 12.1270
# Epoch 22/200
# 7/7 [==============================] - 0s 19ms/step - loss: 37.5750 - mae: 4.6339 - val_loss: 219.3083 - val_mae: 11.5857
# Epoch 23/200
# 7/7 [==============================] - 0s 21ms/step - loss: 33.3993 - mae: 4.1859 - val_loss: 198.6155 - val_mae: 11.4659
# Epoch 24/200
# 7/7 [==============================] - 0s 24ms/step - loss: 31.2257 - mae: 4.1486 - val_loss: 165.4991 - val_mae: 10.7949
# Epoch 25/200
# 7/7 [==============================] - 0s 20ms/step - loss: 26.7927 - mae: 3.8302 - val_loss: 135.0950 - val_mae: 9.8520
# Epoch 26/200
# 7/7 [==============================] - 0s 22ms/step - loss: 22.5914 - mae: 3.5244 - val_loss: 113.1464 - val_mae: 9.3758
# Epoch 27/200
# 7/7 [==============================] - 0s 21ms/step - loss: 17.4500 - mae: 3.0818 - val_loss: 117.4696 - val_mae: 9.2513
# Epoch 28/200
# 7/7 [==============================] - 0s 19ms/step - loss: 15.0419 - mae: 2.8203 - val_loss: 100.7438 - val_mae: 8.4418
# Epoch 29/200
# 7/7 [==============================] - 0s 20ms/step - loss: 13.5317 - mae: 2.7006 - val_loss: 99.9369 - val_mae: 8.5883
# Epoch 30/200
# 7/7 [==============================] - 0s 20ms/step - loss: 11.9369 - mae: 2.5581 - val_loss: 94.9901 - val_mae: 8.1405
# Epoch 31/200
# 7/7 [==============================] - 0s 21ms/step - loss: 10.4940 - mae: 2.4002 - val_loss: 89.4131 - val_mae: 8.1450
# Epoch 32/200
# 7/7 [==============================] - 0s 20ms/step - loss: 9.3557 - mae: 2.2712 - val_loss: 80.1156 - val_mae: 7.6686
# Epoch 33/200
# 7/7 [==============================] - 0s 24ms/step - loss: 8.1807 - mae: 2.1548 - val_loss: 89.5536 - val_mae: 8.1537
# Epoch 34/200
# 7/7 [==============================] - 0s 26ms/step - loss: 7.5020 - mae: 2.0695 - val_loss: 80.2513 - val_mae: 7.6337
# Epoch 35/200
# 7/7 [==============================] - 0s 22ms/step - loss: 6.7323 - mae: 1.9403 - val_loss: 80.3835 - val_mae: 7.6662
# Epoch 36/200
# 7/7 [==============================] - 0s 27ms/step - loss: 6.2540 - mae: 1.8552 - val_loss: 74.7257 - val_mae: 7.3470
# Epoch 37/200
# 7/7 [==============================] - 0s 26ms/step - loss: 5.6811 - mae: 1.7948 - val_loss: 76.0739 - val_mae: 7.3276
# Epoch 38/200
# 7/7 [==============================] - 0s 24ms/step - loss: 5.2175 - mae: 1.7173 - val_loss: 71.9304 - val_mae: 7.1116
# Epoch 39/200
# 7/7 [==============================] - 0s 23ms/step - loss: 4.8316 - mae: 1.6836 - val_loss: 68.6772 - val_mae: 6.9490
# Epoch 40/200
# 7/7 [==============================] - 0s 22ms/step - loss: 4.5687 - mae: 1.6155 - val_loss: 66.4476 - val_mae: 6.6980
# Epoch 41/200
# 7/7 [==============================] - 0s 21ms/step - loss: 4.5509 - mae: 1.6537 - val_loss: 65.0620 - val_mae: 6.7675
# Epoch 42/200
# 7/7 [==============================] - 0s 22ms/step - loss: 4.6011 - mae: 1.6549 - val_loss: 65.0615 - val_mae: 6.7380
# Epoch 43/200
# 7/7 [==============================] - 0s 21ms/step - loss: 5.1932 - mae: 1.7916 - val_loss: 66.7401 - val_mae: 6.8734
# Epoch 44/200
# 7/7 [==============================] - 0s 20ms/step - loss: 5.6940 - mae: 1.8894 - val_loss: 70.5522 - val_mae: 6.9567
# Epoch 45/200
# 7/7 [==============================] - 0s 20ms/step - loss: 7.0394 - mae: 2.1077 - val_loss: 73.8699 - val_mae: 7.1766
# Epoch 46/200
# 7/7 [==============================] - 0s 25ms/step - loss: 8.3699 - mae: 2.3192 - val_loss: 78.9191 - val_mae: 7.2103
# Epoch 47/200
# 7/7 [==============================] - 0s 24ms/step - loss: 9.7902 - mae: 2.4916 - val_loss: 74.2008 - val_mae: 7.0757
# Epoch 48/200
# 7/7 [==============================] - 0s 26ms/step - loss: 9.5704 - mae: 2.5113 - val_loss: 82.2467 - val_mae: 7.3175
# Epoch 49/200
# 7/7 [==============================] - 0s 26ms/step - loss: 9.2129 - mae: 2.4395 - val_loss: 72.6190 - val_mae: 6.8545
# Epoch 50/200
# 7/7 [==============================] - 0s 24ms/step - loss: 7.0578 - mae: 2.1266 - val_loss: 76.6410 - val_mae: 6.9881
# Epoch 51/200
# 7/7 [==============================] - 0s 25ms/step - loss: 5.3514 - mae: 1.8831 - val_loss: 74.1141 - val_mae: 7.1578
# Epoch 52/200
# 7/7 [==============================] - 0s 27ms/step - loss: 5.0745 - mae: 1.5875 - val_loss: 71.8138 - val_mae: 6.8035
# Epoch 53/200
# 7/7 [==============================] - 0s 26ms/step - loss: 4.4676 - mae: 1.4112 - val_loss: 72.5067 - val_mae: 6.8534
# Epoch 54/200
# 7/7 [==============================] - 0s 33ms/step - loss: 3.0751 - mae: 1.2709 - val_loss: 74.9193 - val_mae: 6.7441
# Epoch 55/200
# 7/7 [==============================] - 0s 24ms/step - loss: 2.8631 - mae: 1.2707 - val_loss: 78.6655 - val_mae: 7.0109
# Epoch 56/200
# 7/7 [==============================] - 0s 24ms/step - loss: 2.2209 - mae: 1.0809 - val_loss: 79.4962 - val_mae: 7.1213
# Epoch 57/200
# 7/7 [==============================] - 0s 22ms/step - loss: 1.9289 - mae: 1.0373 - val_loss: 81.1617 - val_mae: 7.1367
# Epoch 58/200
# 7/7 [==============================] - 0s 24ms/step - loss: 1.6268 - mae: 0.9172 - val_loss: 81.8277 - val_mae: 7.1158
# Epoch 59/200
# 7/7 [==============================] - 0s 20ms/step - loss: 1.4880 - mae: 0.8936 - val_loss: 84.3121 - val_mae: 7.1460
# Epoch 60/200
# 7/7 [==============================] - 0s 22ms/step - loss: 1.3746 - mae: 0.8235 - val_loss: 86.2031 - val_mae: 7.1357
# Epoch 61/200
# 7/7 [==============================] - 0s 21ms/step - loss: 1.3037 - mae: 0.8234 - val_loss: 87.5677 - val_mae: 7.1679
# Epoch 62/200
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2154 - mae: 0.7743 - val_loss: 88.1797 - val_mae: 7.1471
# Epoch 63/200
# 7/7 [==============================] - 0s 24ms/step - loss: 1.1692 - mae: 0.7719 - val_loss: 87.9041 - val_mae: 7.1008
# Epoch 64/200
# 7/7 [==============================] - 0s 26ms/step - loss: 1.0998 - mae: 0.7307 - val_loss: 87.5164 - val_mae: 7.0512
# Epoch 65/200
# 7/7 [==============================] - 0s 25ms/step - loss: 1.0701 - mae: 0.7457 - val_loss: 87.2620 - val_mae: 7.0082
# Epoch 66/200
# 7/7 [==============================] - 0s 26ms/step - loss: 1.0182 - mae: 0.7082 - val_loss: 86.2010 - val_mae: 6.9564
# Epoch 67/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.0099 - mae: 0.7350 - val_loss: 86.0696 - val_mae: 6.9200
# Epoch 68/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.9892 - mae: 0.7213 - val_loss: 84.4945 - val_mae: 6.8826
# Epoch 69/200
# 7/7 [==============================] - 0s 25ms/step - loss: 1.0265 - mae: 0.7640 - val_loss: 85.3166 - val_mae: 6.8339
# Epoch 70/200
# 7/7 [==============================] - 0s 29ms/step - loss: 1.0452 - mae: 0.7764 - val_loss: 82.7328 - val_mae: 6.8155
# Epoch 71/200
# 7/7 [==============================] - 0s 26ms/step - loss: 1.1527 - mae: 0.8367 - val_loss: 84.3457 - val_mae: 6.7429
# Epoch 72/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.2376 - mae: 0.8910 - val_loss: 81.2702 - val_mae: 6.7620
# Epoch 73/200
# 7/7 [==============================] - 0s 25ms/step - loss: 1.4726 - mae: 0.9776 - val_loss: 83.1626 - val_mae: 6.6489
# Epoch 74/200
# 7/7 [==============================] - 0s 21ms/step - loss: 1.6975 - mae: 1.0930 - val_loss: 79.6366 - val_mae: 6.7215
# Epoch 75/200
# 7/7 [==============================] - 0s 19ms/step - loss: 2.2415 - mae: 1.2459 - val_loss: 81.3211 - val_mae: 6.5199
# Epoch 76/200
# 7/7 [==============================] - 0s 20ms/step - loss: 2.7460 - mae: 1.4282 - val_loss: 76.6506 - val_mae: 6.6621
# Epoch 77/200
# 7/7 [==============================] - 0s 22ms/step - loss: 3.8428 - mae: 1.6785 - val_loss: 78.2845 - val_mae: 6.3938
# Epoch 78/200
# 7/7 [==============================] - 0s 22ms/step - loss: 4.8951 - mae: 1.9388 - val_loss: 72.4761 - val_mae: 6.5490
# Epoch 79/200
# 7/7 [==============================] - 0s 23ms/step - loss: 6.8775 - mae: 2.2638 - val_loss: 74.0341 - val_mae: 6.3148
# Epoch 80/200
# 7/7 [==============================] - 0s 21ms/step - loss: 8.6731 - mae: 2.5556 - val_loss: 69.8833 - val_mae: 6.3253
# Epoch 81/200
# 7/7 [==============================] - 0s 24ms/step - loss: 11.4110 - mae: 2.9065 - val_loss: 70.9990 - val_mae: 6.3670
# Epoch 82/200
# 7/7 [==============================] - 0s 28ms/step - loss: 13.4752 - mae: 3.1274 - val_loss: 72.0764 - val_mae: 6.5562
# Epoch 83/200
# 7/7 [==============================] - 0s 23ms/step - loss: 15.1610 - mae: 3.2935 - val_loss: 72.1429 - val_mae: 6.4335
# Epoch 84/200
# 7/7 [==============================] - 0s 27ms/step - loss: 15.0165 - mae: 3.2062 - val_loss: 72.5287 - val_mae: 6.5518
# Epoch 85/200
# 7/7 [==============================] - 0s 26ms/step - loss: 12.6285 - mae: 2.9273 - val_loss: 60.5803 - val_mae: 6.0726
# Epoch 86/200
# 7/7 [==============================] - 0s 23ms/step - loss: 8.9977 - mae: 2.4336 - val_loss: 70.6131 - val_mae: 6.2206
# Epoch 87/200
# 7/7 [==============================] - 0s 20ms/step - loss: 5.4595 - mae: 1.9050 - val_loss: 66.8121 - val_mae: 6.2774
# Epoch 88/200
# 7/7 [==============================] - 0s 24ms/step - loss: 3.1391 - mae: 1.3898 - val_loss: 69.7469 - val_mae: 6.3356
# Epoch 89/200
# 7/7 [==============================] - 0s 20ms/step - loss: 1.6462 - mae: 1.0327 - val_loss: 66.7749 - val_mae: 6.2521
# Epoch 90/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9398 - mae: 0.7674 - val_loss: 69.3234 - val_mae: 6.2947
# Epoch 91/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.6761 - mae: 0.6260 - val_loss: 70.8980 - val_mae: 6.3840
# Epoch 92/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5718 - mae: 0.5480 - val_loss: 70.6632 - val_mae: 6.3091
# Epoch 93/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.5116 - mae: 0.5102 - val_loss: 71.7950 - val_mae: 6.3164
# Epoch 94/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4898 - mae: 0.4833 - val_loss: 71.2316 - val_mae: 6.2738
# Epoch 95/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4605 - mae: 0.4702 - val_loss: 71.2828 - val_mae: 6.2641
# Epoch 96/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4447 - mae: 0.4486 - val_loss: 70.6283 - val_mae: 6.2204
# Epoch 97/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.4234 - mae: 0.4370 - val_loss: 70.3969 - val_mae: 6.2014
# Epoch 98/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.4091 - mae: 0.4208 - val_loss: 69.8858 - val_mae: 6.1684
# Epoch 99/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.3933 - mae: 0.4094 - val_loss: 69.5327 - val_mae: 6.1436
# Epoch 100/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3814 - mae: 0.3991 - val_loss: 69.1409 - val_mae: 6.1188
# Epoch 101/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.3693 - mae: 0.3890 - val_loss: 68.8837 - val_mae: 6.0982
# Epoch 102/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3591 - mae: 0.3813 - val_loss: 68.5691 - val_mae: 6.0766
# Epoch 103/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3494 - mae: 0.3738 - val_loss: 68.3201 - val_mae: 6.0564
# Epoch 104/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.3402 - mae: 0.3661 - val_loss: 68.0616 - val_mae: 6.0386
# Epoch 105/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3319 - mae: 0.3617 - val_loss: 67.8680 - val_mae: 6.0197
# Epoch 106/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3237 - mae: 0.3545 - val_loss: 67.6697 - val_mae: 6.0053
# Epoch 107/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.3171 - mae: 0.3519 - val_loss: 67.4885 - val_mae: 5.9872
# Epoch 108/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3098 - mae: 0.3470 - val_loss: 67.3151 - val_mae: 5.9742
# Epoch 109/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.3053 - mae: 0.3455 - val_loss: 67.1504 - val_mae: 5.9589
# Epoch 110/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.2994 - mae: 0.3444 - val_loss: 67.0033 - val_mae: 5.9498
# Epoch 111/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2982 - mae: 0.3456 - val_loss: 66.8440 - val_mae: 5.9319
# Epoch 112/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2952 - mae: 0.3500 - val_loss: 66.7012 - val_mae: 5.9289
# Epoch 113/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3014 - mae: 0.3579 - val_loss: 66.5876 - val_mae: 5.9053
# Epoch 114/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3066 - mae: 0.3731 - val_loss: 66.5118 - val_mae: 5.9195
# Epoch 115/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3293 - mae: 0.3905 - val_loss: 66.3683 - val_mae: 5.8946
# Epoch 116/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.3562 - mae: 0.4241 - val_loss: 66.5077 - val_mae: 5.9106
# Epoch 117/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4210 - mae: 0.4758 - val_loss: 66.2208 - val_mae: 5.8890
# Epoch 118/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.5103 - mae: 0.5371 - val_loss: 66.6769 - val_mae: 5.9243
# Epoch 119/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6754 - mae: 0.6422 - val_loss: 66.1722 - val_mae: 5.8904
# Epoch 120/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.9307 - mae: 0.7673 - val_loss: 67.3998 - val_mae: 5.9748
# Epoch 121/200
# 7/7 [==============================] - 0s 20ms/step - loss: 1.3295 - mae: 0.9269 - val_loss: 66.4901 - val_mae: 5.9028
# Epoch 122/200
# 7/7 [==============================] - 0s 21ms/step - loss: 2.0167 - mae: 1.1482 - val_loss: 69.0786 - val_mae: 6.0421
# Epoch 123/200
# 7/7 [==============================] - 0s 21ms/step - loss: 2.8810 - mae: 1.3668 - val_loss: 67.8446 - val_mae: 5.9335
# Epoch 124/200
# 7/7 [==============================] - 0s 21ms/step - loss: 4.5333 - mae: 1.7226 - val_loss: 73.5323 - val_mae: 6.1651
# Epoch 125/200
# 7/7 [==============================] - 0s 21ms/step - loss: 5.9636 - mae: 1.9439 - val_loss: 71.8469 - val_mae: 6.0485
# Epoch 126/200
# 7/7 [==============================] - 0s 21ms/step - loss: 8.8850 - mae: 2.3857 - val_loss: 84.3830 - val_mae: 6.4570
# Epoch 127/200
# 7/7 [==============================] - 0s 20ms/step - loss: 10.2099 - mae: 2.4671 - val_loss: 86.1178 - val_mae: 6.4455
# Epoch 128/200
# 7/7 [==============================] - 0s 21ms/step - loss: 14.0664 - mae: 2.9135 - val_loss: 221.8698 - val_mae: 8.1398
# Epoch 129/200
# 7/7 [==============================] - 0s 23ms/step - loss: 16.4443 - mae: 2.8616 - val_loss: 207.8526 - val_mae: 7.8984
# Epoch 130/200
# 7/7 [==============================] - 0s 28ms/step - loss: 18.4297 - mae: 3.2453 - val_loss: 217.4977 - val_mae: 9.0101
# Epoch 131/200
# 7/7 [==============================] - 0s 23ms/step - loss: 12.5459 - mae: 2.6121 - val_loss: 188.5668 - val_mae: 7.9446
# Epoch 132/200
# 7/7 [==============================] - 0s 24ms/step - loss: 10.6848 - mae: 2.3671 - val_loss: 230.2471 - val_mae: 9.1054
# Epoch 133/200
# 7/7 [==============================] - 0s 23ms/step - loss: 7.4219 - mae: 1.9664 - val_loss: 105.3581 - val_mae: 6.8685
# Epoch 134/200
# 7/7 [==============================] - 0s 23ms/step - loss: 6.9821 - mae: 2.1392 - val_loss: 97.2356 - val_mae: 8.0499
# Epoch 135/200
# 7/7 [==============================] - 0s 26ms/step - loss: 9.1991 - mae: 2.4598 - val_loss: 136.9369 - val_mae: 7.6276
# Epoch 136/200
# 7/7 [==============================] - 0s 28ms/step - loss: 15.1094 - mae: 3.1559 - val_loss: 115.9202 - val_mae: 8.4673
# Epoch 137/200
# 7/7 [==============================] - 0s 25ms/step - loss: 24.9876 - mae: 4.0543 - val_loss: 144.4090 - val_mae: 7.2690
# Epoch 138/200
# 7/7 [==============================] - 0s 24ms/step - loss: 34.4524 - mae: 4.6648 - val_loss: 144.9181 - val_mae: 8.8789
# Epoch 139/200
# 7/7 [==============================] - 0s 23ms/step - loss: 52.8950 - mae: 5.6742 - val_loss: 135.0627 - val_mae: 7.8126
# Epoch 140/200
# 7/7 [==============================] - 0s 26ms/step - loss: 51.5824 - mae: 5.6253 - val_loss: 55.4116 - val_mae: 5.8106
# Epoch 141/200
# 7/7 [==============================] - 0s 25ms/step - loss: 58.0352 - mae: 5.9536 - val_loss: 88.2036 - val_mae: 7.0458
# Epoch 142/200
# 7/7 [==============================] - 0s 29ms/step - loss: 52.4165 - mae: 5.4120 - val_loss: 61.1755 - val_mae: 6.1036
# Epoch 143/200
# 7/7 [==============================] - 0s 24ms/step - loss: 54.5888 - mae: 5.3689 - val_loss: 294.6797 - val_mae: 9.3381
# Epoch 144/200
# 7/7 [==============================] - 0s 24ms/step - loss: 182.4948 - mae: 8.9223 - val_loss: 376.5772 - val_mae: 14.6800
# Epoch 145/200
# 7/7 [==============================] - 0s 24ms/step - loss: 293.6192 - mae: 14.0432 - val_loss: 368.8982 - val_mae: 14.5796
# Epoch 146/200
# 7/7 [==============================] - 0s 20ms/step - loss: 202.5863 - mae: 10.5867 - val_loss: 909.4192 - val_mae: 18.6420
# Epoch 147/200
# 7/7 [==============================] - 0s 23ms/step - loss: 243.3575 - mae: 10.1009 - val_loss: 134.1320 - val_mae: 9.1127
# Epoch 148/200
# 7/7 [==============================] - 0s 23ms/step - loss: 215.6925 - mae: 10.3591 - val_loss: 263.4605 - val_mae: 12.0749
# Epoch 149/200
# 7/7 [==============================] - 0s 23ms/step - loss: 156.7258 - mae: 9.2525 - val_loss: 210.8584 - val_mae: 11.4613
# Epoch 150/200
# 7/7 [==============================] - 0s 20ms/step - loss: 107.1978 - mae: 7.0532 - val_loss: 283.1075 - val_mae: 13.6374
# Epoch 151/200
# 7/7 [==============================] - 0s 21ms/step - loss: 28.9241 - mae: 3.8074 - val_loss: 231.0063 - val_mae: 11.8985
# Epoch 152/200
# 7/7 [==============================] - 0s 20ms/step - loss: 49.2870 - mae: 5.4947 - val_loss: 104.7939 - val_mae: 7.8987
# Epoch 153/200
# 7/7 [==============================] - 0s 22ms/step - loss: 34.3634 - mae: 4.1505 - val_loss: 132.3504 - val_mae: 9.3684
# Epoch 154/200
# 7/7 [==============================] - 0s 26ms/step - loss: 16.0739 - mae: 2.9337 - val_loss: 86.2881 - val_mae: 7.4188
# Epoch 155/200
# 7/7 [==============================] - 0s 20ms/step - loss: 9.6285 - mae: 2.2350 - val_loss: 66.6280 - val_mae: 6.1063
# Epoch 156/200
# 7/7 [==============================] - 0s 21ms/step - loss: 7.2059 - mae: 1.8919 - val_loss: 78.0284 - val_mae: 6.3486
# Epoch 157/200
# 7/7 [==============================] - 0s 21ms/step - loss: 5.5217 - mae: 1.7279 - val_loss: 93.4243 - val_mae: 7.0073
# Epoch 158/200
# 7/7 [==============================] - 0s 23ms/step - loss: 3.9760 - mae: 1.4702 - val_loss: 95.8385 - val_mae: 6.6230
# Epoch 159/200
# 7/7 [==============================] - 0s 25ms/step - loss: 3.1957 - mae: 1.2857 - val_loss: 88.3085 - val_mae: 6.1026
# Epoch 160/200
# 7/7 [==============================] - 0s 30ms/step - loss: 2.6847 - mae: 1.2280 - val_loss: 83.6805 - val_mae: 5.7029
# Epoch 161/200
# 7/7 [==============================] - 0s 27ms/step - loss: 2.2319 - mae: 1.1194 - val_loss: 80.9851 - val_mae: 5.5584
# Epoch 162/200
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9558 - mae: 1.0492 - val_loss: 83.3778 - val_mae: 5.8308
# Epoch 163/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.7497 - mae: 0.9930 - val_loss: 85.9243 - val_mae: 5.8699
# Epoch 164/200
# 7/7 [==============================] - 0s 21ms/step - loss: 1.5772 - mae: 0.9344 - val_loss: 86.3991 - val_mae: 5.8345
# Epoch 165/200
# 7/7 [==============================] - 0s 25ms/step - loss: 1.4464 - mae: 0.8858 - val_loss: 86.2884 - val_mae: 5.8308
# Epoch 166/200
# 7/7 [==============================] - 0s 26ms/step - loss: 1.3417 - mae: 0.8509 - val_loss: 86.1653 - val_mae: 5.7725
# Epoch 167/200
# 7/7 [==============================] - 0s 24ms/step - loss: 1.2550 - mae: 0.8154 - val_loss: 86.4082 - val_mae: 5.7986
# Epoch 168/200
# 7/7 [==============================] - 0s 21ms/step - loss: 1.1834 - mae: 0.7902 - val_loss: 85.9844 - val_mae: 5.8143
# Epoch 169/200
# 7/7 [==============================] - 0s 20ms/step - loss: 1.1208 - mae: 0.7648 - val_loss: 85.4449 - val_mae: 5.8101
# Epoch 170/200
# 7/7 [==============================] - 0s 26ms/step - loss: 1.0654 - mae: 0.7410 - val_loss: 85.2971 - val_mae: 5.8255
# Epoch 171/200
# 7/7 [==============================] - 0s 24ms/step - loss: 1.0163 - mae: 0.7203 - val_loss: 84.8835 - val_mae: 5.8267
# Epoch 172/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.9722 - mae: 0.7000 - val_loss: 84.4679 - val_mae: 5.8275
# Epoch 173/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.9322 - mae: 0.6824 - val_loss: 84.1020 - val_mae: 5.8269
# Epoch 174/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.8954 - mae: 0.6652 - val_loss: 83.6177 - val_mae: 5.8175
# Epoch 175/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.8610 - mae: 0.6496 - val_loss: 83.1378 - val_mae: 5.8099
# Epoch 176/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.8291 - mae: 0.6360 - val_loss: 82.6740 - val_mae: 5.8019
# Epoch 177/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.7994 - mae: 0.6228 - val_loss: 82.2155 - val_mae: 5.7937
# Epoch 178/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.7715 - mae: 0.6103 - val_loss: 81.7302 - val_mae: 5.7838
# Epoch 179/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7454 - mae: 0.5987 - val_loss: 81.2188 - val_mae: 5.7716
# Epoch 180/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.7206 - mae: 0.5875 - val_loss: 80.7215 - val_mae: 5.7604
# Epoch 181/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.6971 - mae: 0.5767 - val_loss: 80.1861 - val_mae: 5.7460
# Epoch 182/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.6749 - mae: 0.5665 - val_loss: 79.6451 - val_mae: 5.7292
# Epoch 183/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.6540 - mae: 0.5568 - val_loss: 79.0802 - val_mae: 5.7120
# Epoch 184/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6342 - mae: 0.5471 - val_loss: 78.5194 - val_mae: 5.6950
# Epoch 185/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6153 - mae: 0.5378 - val_loss: 77.9860 - val_mae: 5.6771
# Epoch 186/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.5976 - mae: 0.5291 - val_loss: 77.4374 - val_mae: 5.6573
# Epoch 187/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5810 - mae: 0.5208 - val_loss: 76.8860 - val_mae: 5.6375
# Epoch 188/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.5652 - mae: 0.5127 - val_loss: 76.3167 - val_mae: 5.6171
# Epoch 189/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.5502 - mae: 0.5049 - val_loss: 75.7477 - val_mae: 5.5956
# Epoch 190/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.5361 - mae: 0.4975 - val_loss: 75.1692 - val_mae: 5.5728
# Epoch 191/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.5226 - mae: 0.4903 - val_loss: 74.5620 - val_mae: 5.5500
# Epoch 192/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.5098 - mae: 0.4833 - val_loss: 73.9317 - val_mae: 5.5273
# Epoch 193/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.4973 - mae: 0.4765 - val_loss: 73.3052 - val_mae: 5.5042
# Epoch 194/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4855 - mae: 0.4700 - val_loss: 72.6626 - val_mae: 5.4799
# Epoch 195/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4742 - mae: 0.4639 - val_loss: 71.9883 - val_mae: 5.4556
# Epoch 196/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4632 - mae: 0.4580 - val_loss: 71.3033 - val_mae: 5.4322
# Epoch 197/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4525 - mae: 0.4522 - val_loss: 70.6033 - val_mae: 5.4077
# Epoch 198/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4422 - mae: 0.4467 - val_loss: 69.8750 - val_mae: 5.3813
# Epoch 199/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4322 - mae: 0.4415 - val_loss: 69.1199 - val_mae: 5.3547
# Epoch 200/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4225 - mae: 0.4363 - val_loss: 68.3328 - val_mae: 5.3281
# 1/1 [==============================] - 1s 871ms/step

# %% [markdown]
# ## LSTM network for multi-variate time series
#
# Multivariate time series data means data where there is more than one observation for each time step.
#
# There are two main models we may need with multivariate time series data. These are the multiple input series or the multiple parallel series depending on whether we want to predict one or more of the variables.
#
# In this notebook, we focus on the first case: as input, several time series and as output (the prediction), a single time series.

# %% [markdown]
# ### Prepare the data
#
# We reuse the same `series_to_supervise()` function in order to build a dataset with :
# * n_in elements for each series
# * n_out elements for each series to be predict
#
# You have also to select one (Multiple Input Series) or many time series (Multiple Parallel Series) to predict.

# %%
# Get the time series
fct2 = lambda x: 2*x
time_series1 = [fct(x) for x in range(SIZE)]
time_series2 = [fct2(x) for x in range(SIZE)]
out_seq = [time_series1[i]+time_series2[i] for i in range(SIZE)]

# %%
# Get the dataset
dataset = pd.DataFrame(data={"f1":time_series1, "f2":time_series2, "output":out_seq}, index=range(SIZE))
n_features = dataset.shape[1] # for multivariate time series
dataset.head()
# Out:
#          f1  f2    output
# 0  0.000000   0  0.000000
# 1  0.841471   2  2.841471
# 2  1.818595   4  5.818595
# 3  0.423360   6  6.423360
# 4 -3.027210   8  4.972790

# %%
dataset.shape
# Out:
# (250, 3)

# %% [markdown]
# As with the univariate time series, we must structure these data into samples with input and output elements.
# An LSTM model needs sufficient context to learn a mapping from an input sequence to an output value. LSTMs can support parallel input time series as separate variables or features. Therefore, we need to split the data into samples maintaining the order of observations across the two input sequences.
#
# If we chose six input time steps for the three features, we have to transform the dataset in the following way.

# %%
# As previously, prepare the dataset
''' In the followig example, we select 
- n_in number of time steps (6)
- n_out number of time steps of output
- and one serie to predict : output
'''
n_features = dataset.shape[1] # for multivariate time series
n_in = 6
n_out = 1
output = ["output"]

data = series_to_supervised(dataset, n_in, n_out, output=output)
data.head()
# Out:
#      f1(t-6)  f2(t-6)  output(t-6)   f1(t-5)  f2(t-5)  output(t-5)   f1(t-4)  \
# 6   0.000000      0.0     0.000000  0.841471      2.0     2.841471  1.818595
# 7   0.841471      2.0     2.841471  1.818595      4.0     5.818595  0.423360
# 8   1.818595      4.0     5.818595  0.423360      6.0     6.423360 -3.027210
# 9   0.423360      6.0     6.423360 -3.027210      8.0     4.972790 -4.794621
# 10 -3.027210      8.0     4.972790 -4.794621     10.0     5.205379 -1.676493
#
#     f2(t-4)  output(t-4)   f1(t-3)  f2(t-3)  output(t-3)   f1(t-2)  f2(t-2)  \
# 6       4.0     5.818595  0.423360      6.0     6.423360 -3.027210      8.0
# 7       6.0     6.423360 -3.027210      8.0     4.972790 -4.794621     10.0
# 8       8.0     4.972790 -4.794621     10.0     5.205379 -1.676493     12.0
# 9      10.0     5.205379 -1.676493     12.0    10.323507  4.598906     14.0
# 10     12.0    10.323507  4.598906     14.0    18.598906  7.914866     16.0
#
#     output(t-2)   f1(t-1)  f2(t-1)  output(t-1)  output(t)
# 6      4.972790 -4.794621     10.0     5.205379  10.323507
# 7      5.205379 -1.676493     12.0    10.323507  18.598906
# 8     10.323507  4.598906     14.0    18.598906  23.914866
# 9     18.598906  7.914866     16.0    23.914866  21.709066
# 10    23.914866  3.709066     18.0    21.709066  14.559789

# %%
# Split dataset into TRAIN, VAL and TEST
testAndValid = 0.1

SPLIT = int(testAndValid*len(data))
idx_train = len(data)-2*SPLIT
idx_test = len(data)-SPLIT

print("TRAIN=time_series[:"+str(idx_train)+"]")
print("VALID=time_series["+str(idx_train)+":"+str(idx_test)+"]")
print("TEST=time_series["+str(idx_test)+":]")

TRAIN=data[:idx_train]
VAL=data[idx_train:idx_test]
TEST=data[idx_test:]
# Out:
# TRAIN=time_series[:196]
# VALID=time_series[196:220]
# TEST=time_series[220:]

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * build train_X, val_X, test_X and train_y, val_y and test_y as before. Then print the shapes of tensors
#     * train_X is a 3D-tensor (196, 6, 3) for me
#     * train_y is a 1D-tensor (196,)
# </font>

# %%
train_X, train_y = TRAIN.values[:, :-n_out], TRAIN.values[:, -n_out]
val_X, val_y = VAL.values[:, :-n_out], VAL.values[:, -n_out]
test_X, test_y = TEST.values[:, :-n_out], TEST.values[:, -n_out]

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((-1, n_in, n_features))
val_X = val_X.reshape((-1, n_in, n_features))
test_X = test_X.reshape((-1, n_in, n_features))

train_X.shape, train_y.shape
# Out:
# ((196, 6, 3), (196,))

# %% [markdown]
# ### Build a neuronal model

# %% [markdown]
# Any of the varieties of LSTMs in the previous section can be used, such as a Vanilla, Stacked, Bidirectional. It's also possible to use CNN or mixed CNN and LSTM.
#
# We will use a Vanilla LSTM where the number of time steps and parallel series (features) are specified for the input layer via the input_shape argument.

# %%
inputs = Input(shape=(n_in, n_features))
hidden = LSTM(LSTM_SIZE, return_sequences=False, activation='relu')(inputs)
outputs = Dense(n_out, activation='linear')(hidden)
model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 6, 3)]            0
#
#  lstm_7 (LSTM)               (None, 16)                1280
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,297
# Trainable params: 1,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = build_and_fit(model, train_X, train_y, val_X, val_y, test_X, test_y)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 2s 81ms/step - loss: 61786.2109 - mae: 206.0839 - val_loss: 205863.3750 - val_mae: 427.3520
# Epoch 2/200
# 7/7 [==============================] - 0s 12ms/step - loss: 61781.3438 - mae: 206.0562 - val_loss: 205857.9219 - val_mae: 427.3456
# Epoch 3/200
# 7/7 [==============================] - 0s 11ms/step - loss: 61777.9883 - mae: 206.0411 - val_loss: 205852.4219 - val_mae: 427.3392
# Epoch 4/200
# 7/7 [==============================] - 0s 11ms/step - loss: 61774.8359 - mae: 206.0280 - val_loss: 205846.9844 - val_mae: 427.3329
# Epoch 5/200
# 7/7 [==============================] - 0s 11ms/step - loss: 61771.5781 - mae: 206.0139 - val_loss: 205841.5000 - val_mae: 427.3264
# Epoch 6/200
# 7/7 [==============================] - 0s 11ms/step - loss: 61767.8711 - mae: 205.9960 - val_loss: 205836.0781 - val_mae: 427.3201
# Epoch 7/200
# 7/7 [==============================] - 0s 16ms/step - loss: 61762.9180 - mae: 205.9688 - val_loss: 205830.6719 - val_mae: 427.3137
# Epoch 8/200
# 7/7 [==============================] - 0s 11ms/step - loss: 61752.5820 - mae: 205.9129 - val_loss: 205824.3594 - val_mae: 427.3064
# Epoch 9/200
# 7/7 [==============================] - 0s 11ms/step - loss: 61625.0039 - mae: 205.5832 - val_loss: 204483.0781 - val_mae: 425.8462
# Epoch 10/200
# 7/7 [==============================] - 0s 16ms/step - loss: 55842.0312 - mae: 195.7787 - val_loss: 163859.1094 - val_mae: 375.3818
# Epoch 11/200
# 7/7 [==============================] - 0s 18ms/step - loss: 42271.0625 - mae: 167.0864 - val_loss: 127159.4062 - val_mae: 314.5083
# Epoch 12/200
# 7/7 [==============================] - 0s 19ms/step - loss: 36766.5273 - mae: 148.5709 - val_loss: 111468.3750 - val_mae: 282.3731
# Epoch 13/200
# 7/7 [==============================] - 0s 13ms/step - loss: 27520.8887 - mae: 120.0855 - val_loss: 83511.3594 - val_mae: 226.8245
# Epoch 14/200
# 7/7 [==============================] - 0s 12ms/step - loss: 19414.3711 - mae: 98.7062 - val_loss: 49914.3711 - val_mae: 172.2786
# Epoch 15/200
# 7/7 [==============================] - 0s 11ms/step - loss: 14393.8086 - mae: 85.3573 - val_loss: 40581.1914 - val_mae: 157.7095
# Epoch 16/200
# 7/7 [==============================] - 0s 12ms/step - loss: 11140.7090 - mae: 79.9575 - val_loss: 30512.7871 - val_mae: 142.1351
# Epoch 17/200
# 7/7 [==============================] - 0s 12ms/step - loss: 9723.3457 - mae: 76.6751 - val_loss: 26803.1465 - val_mae: 136.4803
# Epoch 18/200
# 7/7 [==============================] - 0s 13ms/step - loss: 8409.7090 - mae: 71.0900 - val_loss: 23687.8105 - val_mae: 131.2319
# Epoch 19/200
# 7/7 [==============================] - 0s 16ms/step - loss: 6392.5244 - mae: 65.5234 - val_loss: 15792.7588 - val_mae: 112.5593
# Epoch 20/200
# 7/7 [==============================] - 0s 17ms/step - loss: 3372.6375 - mae: 47.6554 - val_loss: 8723.9971 - val_mae: 81.5440
# Epoch 21/200
# 7/7 [==============================] - 0s 13ms/step - loss: 2471.3198 - mae: 38.0624 - val_loss: 7349.8179 - val_mae: 72.3557
# Epoch 22/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2173.0046 - mae: 34.5138 - val_loss: 6234.1777 - val_mae: 61.7291
# Epoch 23/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1870.5713 - mae: 31.4068 - val_loss: 5946.1860 - val_mae: 60.5048
# Epoch 24/200
# 7/7 [==============================] - 0s 19ms/step - loss: 1659.2344 - mae: 29.1671 - val_loss: 5157.7344 - val_mae: 56.6680
# Epoch 25/200
# 7/7 [==============================] - 0s 15ms/step - loss: 1465.0260 - mae: 27.9076 - val_loss: 4571.1772 - val_mae: 54.2144
# Epoch 26/200
# 7/7 [==============================] - 0s 17ms/step - loss: 1261.7991 - mae: 25.4271 - val_loss: 3803.3147 - val_mae: 47.5369
# Epoch 27/200
# 7/7 [==============================] - 0s 18ms/step - loss: 1148.9454 - mae: 24.3630 - val_loss: 3611.5500 - val_mae: 46.3355
# Epoch 28/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1005.3792 - mae: 23.1527 - val_loss: 2744.3059 - val_mae: 41.6732
# Epoch 29/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1152.0408 - mae: 24.1501 - val_loss: 3479.7881 - val_mae: 46.4749
# Epoch 30/200
# 7/7 [==============================] - 0s 10ms/step - loss: 681.2820 - mae: 18.8796 - val_loss: 1861.3418 - val_mae: 35.8873
# Epoch 31/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1173.0388 - mae: 25.7672 - val_loss: 2905.0466 - val_mae: 44.3841
# Epoch 32/200
# 7/7 [==============================] - 0s 9ms/step - loss: 1085.1180 - mae: 23.9242 - val_loss: 3829.3411 - val_mae: 48.4335
# Epoch 33/200
# 7/7 [==============================] - 0s 8ms/step - loss: 1196.7023 - mae: 25.3150 - val_loss: 3418.3860 - val_mae: 46.6047
# Epoch 34/200
# 7/7 [==============================] - 0s 8ms/step - loss: 971.4747 - mae: 22.8466 - val_loss: 2762.7734 - val_mae: 42.6062
# Epoch 35/200
# 7/7 [==============================] - 0s 9ms/step - loss: 656.5980 - mae: 18.3625 - val_loss: 2629.0339 - val_mae: 39.9730
# Epoch 36/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1273.8617 - mae: 23.9294 - val_loss: 4029.0881 - val_mae: 48.6447
# Epoch 37/200
# 7/7 [==============================] - 0s 9ms/step - loss: 953.8313 - mae: 22.7011 - val_loss: 1904.1025 - val_mae: 36.9475
# Epoch 38/200
# 7/7 [==============================] - 0s 10ms/step - loss: 565.2895 - mae: 17.8137 - val_loss: 1298.1405 - val_mae: 29.9856
# Epoch 39/200
# 7/7 [==============================] - 0s 9ms/step - loss: 610.1816 - mae: 17.8378 - val_loss: 2570.8550 - val_mae: 38.6569
# Epoch 40/200
# 7/7 [==============================] - 0s 8ms/step - loss: 790.5610 - mae: 20.1691 - val_loss: 1480.2711 - val_mae: 30.6363
# Epoch 41/200
# 7/7 [==============================] - 0s 10ms/step - loss: 837.1485 - mae: 21.2611 - val_loss: 2239.8259 - val_mae: 38.6031
# Epoch 42/200
# 7/7 [==============================] - 0s 10ms/step - loss: 423.3345 - mae: 15.8929 - val_loss: 1648.1627 - val_mae: 34.4090
# Epoch 43/200
# 7/7 [==============================] - 0s 9ms/step - loss: 711.2279 - mae: 19.6774 - val_loss: 1958.4286 - val_mae: 36.7206
# Epoch 44/200
# 7/7 [==============================] - 0s 8ms/step - loss: 488.0875 - mae: 17.0024 - val_loss: 2127.8738 - val_mae: 38.8295
# Epoch 45/200
# 7/7 [==============================] - 0s 9ms/step - loss: 544.3293 - mae: 17.4002 - val_loss: 2522.2522 - val_mae: 39.6251
# Epoch 46/200
# 7/7 [==============================] - 0s 9ms/step - loss: 564.2736 - mae: 17.0967 - val_loss: 1823.5533 - val_mae: 33.8504
# Epoch 47/200
# 7/7 [==============================] - 0s 9ms/step - loss: 1182.2648 - mae: 22.9259 - val_loss: 2629.2947 - val_mae: 37.1944
# Epoch 48/200
# 7/7 [==============================] - 0s 9ms/step - loss: 996.9604 - mae: 22.0145 - val_loss: 2651.7463 - val_mae: 42.2515
# Epoch 49/200
# 7/7 [==============================] - 0s 8ms/step - loss: 990.3177 - mae: 23.3633 - val_loss: 2976.8789 - val_mae: 45.6587
# Epoch 50/200
# 7/7 [==============================] - 0s 8ms/step - loss: 925.8542 - mae: 21.6055 - val_loss: 2066.0381 - val_mae: 37.3810
# Epoch 51/200
# 7/7 [==============================] - 0s 8ms/step - loss: 916.0500 - mae: 20.9872 - val_loss: 2566.8928 - val_mae: 36.9616
# Epoch 52/200
# 7/7 [==============================] - 0s 8ms/step - loss: 748.6244 - mae: 19.4990 - val_loss: 2358.8845 - val_mae: 38.3850
# Epoch 53/200
# 7/7 [==============================] - 0s 8ms/step - loss: 782.4451 - mae: 19.7742 - val_loss: 2542.8293 - val_mae: 38.6844
# Epoch 54/200
# 7/7 [==============================] - 0s 8ms/step - loss: 633.9546 - mae: 17.7417 - val_loss: 1639.1049 - val_mae: 33.0558
# Epoch 55/200
# 7/7 [==============================] - 0s 9ms/step - loss: 9160.9229 - mae: 25.1094 - val_loss: 1308.1847 - val_mae: 29.9523
# Epoch 56/200
# 7/7 [==============================] - 0s 11ms/step - loss: 634.6074 - mae: 17.2459 - val_loss: 986.3427 - val_mae: 25.3208
# Epoch 57/200
# 7/7 [==============================] - 0s 9ms/step - loss: 585.8589 - mae: 16.6160 - val_loss: 2041.0358 - val_mae: 34.1955
# Epoch 58/200
# 7/7 [==============================] - 0s 8ms/step - loss: 646.2258 - mae: 17.2526 - val_loss: 2313.4734 - val_mae: 35.7968
# Epoch 59/200
# 7/7 [==============================] - 0s 9ms/step - loss: 649.3434 - mae: 17.6345 - val_loss: 2032.4268 - val_mae: 32.4349
# Epoch 60/200
# 7/7 [==============================] - 0s 9ms/step - loss: 532.0597 - mae: 16.1865 - val_loss: 1839.3135 - val_mae: 32.4920
# Epoch 61/200
# 7/7 [==============================] - 0s 8ms/step - loss: 501.3624 - mae: 15.5476 - val_loss: 1546.4655 - val_mae: 29.5726
# Epoch 62/200
# 7/7 [==============================] - 0s 9ms/step - loss: 515.7881 - mae: 16.1104 - val_loss: 1424.3605 - val_mae: 29.9472
# Epoch 63/200
# 7/7 [==============================] - 0s 13ms/step - loss: 408.1913 - mae: 15.2693 - val_loss: 1443.5654 - val_mae: 31.0226
# Epoch 64/200
# 7/7 [==============================] - 0s 9ms/step - loss: 291.5280 - mae: 12.6901 - val_loss: 947.0032 - val_mae: 24.1321
# Epoch 65/200
# 7/7 [==============================] - 0s 10ms/step - loss: 250.0328 - mae: 11.5829 - val_loss: 899.5063 - val_mae: 23.1797
# Epoch 66/200
# 7/7 [==============================] - 0s 8ms/step - loss: 259.1723 - mae: 11.7458 - val_loss: 862.5065 - val_mae: 21.1568
# Epoch 67/200
# 7/7 [==============================] - 0s 8ms/step - loss: 275.6575 - mae: 11.9159 - val_loss: 1022.7376 - val_mae: 24.0679
# Epoch 68/200
# 7/7 [==============================] - 0s 12ms/step - loss: 259.5287 - mae: 11.7778 - val_loss: 1230.7322 - val_mae: 26.8297
# Epoch 69/200
# 7/7 [==============================] - 0s 8ms/step - loss: 218.9870 - mae: 10.7000 - val_loss: 1038.1079 - val_mae: 25.5192
# Epoch 70/200
# 7/7 [==============================] - 0s 8ms/step - loss: 1922.9128 - mae: 28.5983 - val_loss: 6148.6509 - val_mae: 59.1706
# Epoch 71/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1639.7969 - mae: 29.0192 - val_loss: 6058.1870 - val_mae: 67.5309
# Epoch 72/200
# 7/7 [==============================] - 0s 8ms/step - loss: 1236.7485 - mae: 25.8864 - val_loss: 3899.8535 - val_mae: 50.0662
# Epoch 73/200
# 7/7 [==============================] - 0s 10ms/step - loss: 783.9888 - mae: 20.4259 - val_loss: 2098.2463 - val_mae: 37.3639
# Epoch 74/200
# 7/7 [==============================] - 0s 9ms/step - loss: 819.6339 - mae: 20.1758 - val_loss: 3149.0059 - val_mae: 44.3140
# Epoch 75/200
# 7/7 [==============================] - 0s 8ms/step - loss: 889.5783 - mae: 21.6126 - val_loss: 2673.3604 - val_mae: 42.2502
# Epoch 76/200
# 7/7 [==============================] - 0s 9ms/step - loss: 718.2714 - mae: 20.0485 - val_loss: 2276.6843 - val_mae: 38.2218
# Epoch 77/200
# 7/7 [==============================] - 0s 9ms/step - loss: 633.6658 - mae: 19.1486 - val_loss: 2060.8970 - val_mae: 36.7707
# Epoch 78/200
# 7/7 [==============================] - 0s 8ms/step - loss: 553.7086 - mae: 17.5967 - val_loss: 1901.4547 - val_mae: 35.6635
# Epoch 79/200
# 7/7 [==============================] - 0s 8ms/step - loss: 500.1405 - mae: 16.7425 - val_loss: 1753.6488 - val_mae: 34.5852
# Epoch 80/200
# 7/7 [==============================] - 0s 8ms/step - loss: 465.7004 - mae: 16.2583 - val_loss: 1600.8877 - val_mae: 32.6748
# Epoch 81/200
# 7/7 [==============================] - 0s 8ms/step - loss: 437.3508 - mae: 15.6382 - val_loss: 1340.2643 - val_mae: 30.1385
# Epoch 82/200
# 7/7 [==============================] - 0s 8ms/step - loss: 387.8337 - mae: 14.8425 - val_loss: 1207.1064 - val_mae: 29.5164
# Epoch 83/200
# 7/7 [==============================] - 0s 8ms/step - loss: 338.6702 - mae: 14.1439 - val_loss: 1089.2039 - val_mae: 27.4179
# Epoch 84/200
# 7/7 [==============================] - 0s 8ms/step - loss: 320.1749 - mae: 13.7357 - val_loss: 1056.6173 - val_mae: 27.5012
# Epoch 85/200
# 7/7 [==============================] - 0s 8ms/step - loss: 283.8067 - mae: 12.9536 - val_loss: 887.9543 - val_mae: 24.8052
# Epoch 86/200
# 7/7 [==============================] - 0s 10ms/step - loss: 245.1273 - mae: 11.8567 - val_loss: 853.9378 - val_mae: 24.9261
# Epoch 87/200
# 7/7 [==============================] - 0s 8ms/step - loss: 212.7554 - mae: 11.0878 - val_loss: 715.2488 - val_mae: 22.7248
# Epoch 88/200
# 7/7 [==============================] - 0s 10ms/step - loss: 192.0779 - mae: 10.4125 - val_loss: 582.6660 - val_mae: 20.4484
# Epoch 89/200
# 7/7 [==============================] - 0s 9ms/step - loss: 174.2572 - mae: 9.8391 - val_loss: 449.7041 - val_mae: 17.9555
# Epoch 90/200
# 7/7 [==============================] - 0s 9ms/step - loss: 157.8036 - mae: 9.3784 - val_loss: 403.5469 - val_mae: 16.8602
# Epoch 91/200
# 7/7 [==============================] - 0s 8ms/step - loss: 141.5022 - mae: 8.8490 - val_loss: 354.2396 - val_mae: 15.7102
# Epoch 92/200
# 7/7 [==============================] - 0s 9ms/step - loss: 123.2501 - mae: 8.2512 - val_loss: 293.6341 - val_mae: 14.1036
# Epoch 93/200
# 7/7 [==============================] - 0s 9ms/step - loss: 114.4509 - mae: 7.9716 - val_loss: 276.3484 - val_mae: 13.5522
# Epoch 94/200
# 7/7 [==============================] - 0s 10ms/step - loss: 108.2064 - mae: 7.7617 - val_loss: 261.7138 - val_mae: 13.3877
# Epoch 95/200
# 7/7 [==============================] - 0s 9ms/step - loss: 103.8972 - mae: 7.6198 - val_loss: 247.8960 - val_mae: 13.0312
# Epoch 96/200
# 7/7 [==============================] - 0s 9ms/step - loss: 100.3192 - mae: 7.4547 - val_loss: 240.3930 - val_mae: 13.0318
# Epoch 97/200
# 7/7 [==============================] - 0s 10ms/step - loss: 97.0972 - mae: 7.3170 - val_loss: 238.7805 - val_mae: 13.1265
# Epoch 98/200
# 7/7 [==============================] - 0s 9ms/step - loss: 95.5381 - mae: 7.2015 - val_loss: 243.3411 - val_mae: 13.3064
# Epoch 99/200
# 7/7 [==============================] - 0s 9ms/step - loss: 94.3781 - mae: 7.2167 - val_loss: 232.4224 - val_mae: 12.9706
# Epoch 100/200
# 7/7 [==============================] - 0s 9ms/step - loss: 94.8601 - mae: 7.2033 - val_loss: 238.8917 - val_mae: 13.1874
# Epoch 101/200
# 7/7 [==============================] - 0s 10ms/step - loss: 94.7529 - mae: 7.1787 - val_loss: 239.8208 - val_mae: 13.3205
# Epoch 102/200
# 7/7 [==============================] - 0s 9ms/step - loss: 91.9844 - mae: 7.1348 - val_loss: 236.3400 - val_mae: 13.1979
# Epoch 103/200
# 7/7 [==============================] - 0s 12ms/step - loss: 91.1092 - mae: 7.0327 - val_loss: 231.8128 - val_mae: 13.0259
# Epoch 104/200
# 7/7 [==============================] - 0s 9ms/step - loss: 89.3373 - mae: 7.0152 - val_loss: 239.5277 - val_mae: 13.1929
# Epoch 105/200
# 7/7 [==============================] - 0s 10ms/step - loss: 88.3953 - mae: 6.9897 - val_loss: 238.4401 - val_mae: 13.0864
# Epoch 106/200
# 7/7 [==============================] - 0s 10ms/step - loss: 87.1817 - mae: 6.9303 - val_loss: 238.4824 - val_mae: 13.0211
# Epoch 107/200
# 7/7 [==============================] - 0s 11ms/step - loss: 86.0426 - mae: 6.8989 - val_loss: 240.2821 - val_mae: 12.9751
# Epoch 108/200
# 7/7 [==============================] - 0s 10ms/step - loss: 86.4481 - mae: 6.8586 - val_loss: 231.9885 - val_mae: 12.7338
# Epoch 109/200
# 7/7 [==============================] - 0s 10ms/step - loss: 83.4783 - mae: 6.8210 - val_loss: 252.2341 - val_mae: 13.2066
# Epoch 110/200
# 7/7 [==============================] - 0s 10ms/step - loss: 83.3321 - mae: 6.8344 - val_loss: 246.5514 - val_mae: 13.0457
# Epoch 111/200
# 7/7 [==============================] - 0s 14ms/step - loss: 82.1415 - mae: 6.7797 - val_loss: 237.3573 - val_mae: 12.5965
# Epoch 112/200
# 7/7 [==============================] - 0s 11ms/step - loss: 81.1585 - mae: 6.7795 - val_loss: 284.4934 - val_mae: 13.7268
# Epoch 113/200
# 7/7 [==============================] - 0s 12ms/step - loss: 79.7345 - mae: 6.6412 - val_loss: 320.1347 - val_mae: 13.9190
# Epoch 114/200
# 7/7 [==============================] - 0s 10ms/step - loss: 84.2665 - mae: 7.0310 - val_loss: 295.9592 - val_mae: 13.5559
# Epoch 115/200
# 7/7 [==============================] - 0s 10ms/step - loss: 87.5636 - mae: 7.0125 - val_loss: 330.1235 - val_mae: 14.3296
# Epoch 116/200
# 7/7 [==============================] - 0s 9ms/step - loss: 80.1145 - mae: 6.9174 - val_loss: 343.1986 - val_mae: 14.4705
# Epoch 117/200
# 7/7 [==============================] - 0s 9ms/step - loss: 83.8479 - mae: 6.9280 - val_loss: 336.9047 - val_mae: 14.4121
# Epoch 118/200
# 7/7 [==============================] - 0s 10ms/step - loss: 78.6184 - mae: 6.8329 - val_loss: 345.9423 - val_mae: 14.7808
# Epoch 119/200
# 7/7 [==============================] - 0s 9ms/step - loss: 79.4149 - mae: 6.7477 - val_loss: 349.2498 - val_mae: 14.7835
# Epoch 120/200
# 7/7 [==============================] - 0s 9ms/step - loss: 76.4010 - mae: 6.7100 - val_loss: 354.7605 - val_mae: 14.8437
# Epoch 121/200
# 7/7 [==============================] - 0s 9ms/step - loss: 76.0116 - mae: 6.6416 - val_loss: 348.9452 - val_mae: 14.7097
# Epoch 122/200
# 7/7 [==============================] - 0s 12ms/step - loss: 73.6355 - mae: 6.5665 - val_loss: 332.3940 - val_mae: 14.3566
# Epoch 123/200
# 7/7 [==============================] - 0s 9ms/step - loss: 73.1366 - mae: 6.5391 - val_loss: 327.5451 - val_mae: 14.1416
# Epoch 124/200
# 7/7 [==============================] - 0s 9ms/step - loss: 72.1503 - mae: 6.5194 - val_loss: 337.0548 - val_mae: 14.4661
# Epoch 125/200
# 7/7 [==============================] - 0s 10ms/step - loss: 72.1956 - mae: 6.4723 - val_loss: 338.3377 - val_mae: 14.5329
# Epoch 126/200
# 7/7 [==============================] - 0s 9ms/step - loss: 69.9586 - mae: 6.4207 - val_loss: 339.4439 - val_mae: 14.3780
# Epoch 127/200
# 7/7 [==============================] - 0s 10ms/step - loss: 71.5352 - mae: 6.4429 - val_loss: 310.0199 - val_mae: 14.0821
# Epoch 128/200
# 7/7 [==============================] - 0s 9ms/step - loss: 69.1302 - mae: 6.3841 - val_loss: 313.8102 - val_mae: 14.0864
# Epoch 129/200
# 7/7 [==============================] - 0s 11ms/step - loss: 74.1578 - mae: 6.5041 - val_loss: 299.2192 - val_mae: 14.0345
# Epoch 130/200
# 7/7 [==============================] - 0s 10ms/step - loss: 70.4215 - mae: 6.5072 - val_loss: 297.7817 - val_mae: 14.1299
# Epoch 131/200
# 7/7 [==============================] - 0s 9ms/step - loss: 81.2995 - mae: 6.5954 - val_loss: 260.6742 - val_mae: 13.2694
# Epoch 132/200
# 7/7 [==============================] - 0s 10ms/step - loss: 72.0876 - mae: 6.5559 - val_loss: 239.5036 - val_mae: 12.8009
# Epoch 133/200
# 7/7 [==============================] - 0s 9ms/step - loss: 72.1480 - mae: 6.4942 - val_loss: 249.8489 - val_mae: 12.5902
# Epoch 134/200
# 7/7 [==============================] - 0s 11ms/step - loss: 69.2767 - mae: 6.3604 - val_loss: 317.3903 - val_mae: 14.0793
# Epoch 135/200
# 7/7 [==============================] - 0s 8ms/step - loss: 67.6420 - mae: 6.2597 - val_loss: 327.7140 - val_mae: 14.3249
# Epoch 136/200
# 7/7 [==============================] - 0s 9ms/step - loss: 65.7573 - mae: 6.2090 - val_loss: 322.1164 - val_mae: 14.2371
# Epoch 137/200
# 7/7 [==============================] - 0s 8ms/step - loss: 66.2842 - mae: 6.1931 - val_loss: 316.0459 - val_mae: 13.8518
# Epoch 138/200
# 7/7 [==============================] - 0s 8ms/step - loss: 63.7955 - mae: 6.0399 - val_loss: 308.1411 - val_mae: 13.5579
# Epoch 139/200
# 7/7 [==============================] - 0s 8ms/step - loss: 65.4604 - mae: 6.0692 - val_loss: 298.7272 - val_mae: 13.6571
# Epoch 140/200
# 7/7 [==============================] - 0s 9ms/step - loss: 64.6946 - mae: 6.0207 - val_loss: 305.0784 - val_mae: 14.0599
# Epoch 141/200
# 7/7 [==============================] - 0s 12ms/step - loss: 68.9934 - mae: 6.1872 - val_loss: 280.5723 - val_mae: 13.9125
# Epoch 142/200
# 7/7 [==============================] - 0s 9ms/step - loss: 67.5615 - mae: 6.3414 - val_loss: 269.7672 - val_mae: 13.5724
# Epoch 143/200
# 7/7 [==============================] - 0s 12ms/step - loss: 75.1372 - mae: 6.2990 - val_loss: 276.6805 - val_mae: 13.4049
# Epoch 144/200
# 7/7 [==============================] - 0s 9ms/step - loss: 66.9768 - mae: 6.3335 - val_loss: 273.2374 - val_mae: 13.3353
# Epoch 145/200
# 7/7 [==============================] - 0s 12ms/step - loss: 66.9964 - mae: 6.1504 - val_loss: 298.5062 - val_mae: 13.6097
# Epoch 146/200
# 7/7 [==============================] - 0s 9ms/step - loss: 63.2462 - mae: 5.9985 - val_loss: 302.8178 - val_mae: 13.5052
# Epoch 147/200
# 7/7 [==============================] - 0s 9ms/step - loss: 62.0508 - mae: 5.9784 - val_loss: 286.2843 - val_mae: 13.3183
# Epoch 148/200
# 7/7 [==============================] - 0s 9ms/step - loss: 62.1433 - mae: 5.9675 - val_loss: 296.4330 - val_mae: 13.3823
# Epoch 149/200
# 7/7 [==============================] - 0s 9ms/step - loss: 60.5387 - mae: 5.9161 - val_loss: 268.1270 - val_mae: 12.8369
# Epoch 150/200
# 7/7 [==============================] - 0s 9ms/step - loss: 62.0424 - mae: 5.9356 - val_loss: 250.3972 - val_mae: 12.5675
# Epoch 151/200
# 7/7 [==============================] - 0s 11ms/step - loss: 89.6133 - mae: 6.9004 - val_loss: 257.8144 - val_mae: 12.8252
# Epoch 152/200
# 7/7 [==============================] - 0s 10ms/step - loss: 69.9681 - mae: 6.4554 - val_loss: 271.8936 - val_mae: 13.6410
# Epoch 153/200
# 7/7 [==============================] - 0s 10ms/step - loss: 67.7021 - mae: 6.2335 - val_loss: 282.2900 - val_mae: 12.7973
# Epoch 154/200
# 7/7 [==============================] - 0s 11ms/step - loss: 61.6043 - mae: 5.8451 - val_loss: 296.8863 - val_mae: 13.2384
# Epoch 155/200
# 7/7 [==============================] - 0s 14ms/step - loss: 63.5289 - mae: 5.9892 - val_loss: 278.0990 - val_mae: 13.5321
# Epoch 156/200
# 7/7 [==============================] - 0s 13ms/step - loss: 61.5005 - mae: 6.0002 - val_loss: 292.0391 - val_mae: 13.6176
# Epoch 157/200
# 7/7 [==============================] - 0s 10ms/step - loss: 60.0222 - mae: 5.8859 - val_loss: 279.7772 - val_mae: 13.1478
# Epoch 158/200
# 7/7 [==============================] - 0s 13ms/step - loss: 59.8914 - mae: 5.8175 - val_loss: 267.8681 - val_mae: 12.8946
# Epoch 159/200
# 7/7 [==============================] - 0s 9ms/step - loss: 64.6775 - mae: 5.9162 - val_loss: 250.0065 - val_mae: 13.0906
# Epoch 160/200
# 7/7 [==============================] - 0s 9ms/step - loss: 60.6946 - mae: 5.8683 - val_loss: 263.1994 - val_mae: 13.1936
# Epoch 161/200
# 7/7 [==============================] - 0s 10ms/step - loss: 58.5723 - mae: 5.8816 - val_loss: 266.2975 - val_mae: 12.6271
# Epoch 162/200
# 7/7 [==============================] - 0s 9ms/step - loss: 58.4458 - mae: 5.6795 - val_loss: 279.7080 - val_mae: 13.0685
# Epoch 163/200
# 7/7 [==============================] - 0s 9ms/step - loss: 56.4142 - mae: 5.6582 - val_loss: 262.6285 - val_mae: 12.8625
# Epoch 164/200
# 7/7 [==============================] - 0s 9ms/step - loss: 56.7927 - mae: 5.6696 - val_loss: 248.2839 - val_mae: 12.3955
# Epoch 165/200
# 7/7 [==============================] - 0s 9ms/step - loss: 55.4777 - mae: 5.5971 - val_loss: 251.6940 - val_mae: 12.1638
# Epoch 166/200
# 7/7 [==============================] - 0s 12ms/step - loss: 54.4879 - mae: 5.5330 - val_loss: 238.3318 - val_mae: 12.0524
# Epoch 167/200
# 7/7 [==============================] - 0s 14ms/step - loss: 54.9161 - mae: 5.5113 - val_loss: 231.8935 - val_mae: 11.8789
# Epoch 168/200
# 7/7 [==============================] - 0s 10ms/step - loss: 54.2769 - mae: 5.5702 - val_loss: 227.6399 - val_mae: 11.9055
# Epoch 169/200
# 7/7 [==============================] - 0s 9ms/step - loss: 55.8377 - mae: 5.4762 - val_loss: 219.4456 - val_mae: 11.1580
# Epoch 170/200
# 7/7 [==============================] - 0s 10ms/step - loss: 57.2879 - mae: 5.6311 - val_loss: 220.8549 - val_mae: 11.8046
# Epoch 171/200
# 7/7 [==============================] - 0s 9ms/step - loss: 63.0671 - mae: 5.8618 - val_loss: 238.1960 - val_mae: 11.4977
# Epoch 172/200
# 7/7 [==============================] - 0s 8ms/step - loss: 62.5332 - mae: 5.6380 - val_loss: 214.3467 - val_mae: 11.0072
# Epoch 173/200
# 7/7 [==============================] - 0s 9ms/step - loss: 59.5140 - mae: 5.7846 - val_loss: 250.3453 - val_mae: 12.4222
# Epoch 174/200
# 7/7 [==============================] - 0s 8ms/step - loss: 54.7332 - mae: 5.6784 - val_loss: 228.2482 - val_mae: 11.5374
# Epoch 175/200
# 7/7 [==============================] - 0s 9ms/step - loss: 55.3080 - mae: 5.4432 - val_loss: 225.7577 - val_mae: 11.4859
# Epoch 176/200
# 7/7 [==============================] - 0s 9ms/step - loss: 55.9169 - mae: 5.5562 - val_loss: 224.1408 - val_mae: 11.4240
# Epoch 177/200
# 7/7 [==============================] - 0s 9ms/step - loss: 56.0743 - mae: 5.4433 - val_loss: 214.3966 - val_mae: 10.9338
# Epoch 178/200
# 7/7 [==============================] - 0s 9ms/step - loss: 55.3729 - mae: 5.5949 - val_loss: 220.9939 - val_mae: 11.4441
# Epoch 179/200
# 7/7 [==============================] - 0s 9ms/step - loss: 65.8540 - mae: 5.8454 - val_loss: 240.2688 - val_mae: 11.6853
# Epoch 180/200
# 7/7 [==============================] - 0s 9ms/step - loss: 64.4618 - mae: 5.6650 - val_loss: 198.6478 - val_mae: 11.4672
# Epoch 181/200
# 7/7 [==============================] - 0s 9ms/step - loss: 63.4920 - mae: 6.0139 - val_loss: 215.7200 - val_mae: 11.9740
# Epoch 182/200
# 7/7 [==============================] - 0s 10ms/step - loss: 58.9214 - mae: 5.5950 - val_loss: 252.5685 - val_mae: 12.0819
# Epoch 183/200
# 7/7 [==============================] - 0s 9ms/step - loss: 55.2613 - mae: 5.4081 - val_loss: 233.8988 - val_mae: 11.7826
# Epoch 184/200
# 7/7 [==============================] - 0s 9ms/step - loss: 58.2967 - mae: 5.4682 - val_loss: 205.8285 - val_mae: 11.8152
# Epoch 185/200
# 7/7 [==============================] - 0s 10ms/step - loss: 56.1146 - mae: 5.4791 - val_loss: 248.9895 - val_mae: 12.5641
# Epoch 186/200
# 7/7 [==============================] - 0s 9ms/step - loss: 53.9805 - mae: 5.4968 - val_loss: 264.6731 - val_mae: 12.0601
# Epoch 187/200
# 7/7 [==============================] - 0s 9ms/step - loss: 52.9737 - mae: 5.2659 - val_loss: 262.4088 - val_mae: 12.2955
# Epoch 188/200
# 7/7 [==============================] - 0s 8ms/step - loss: 53.4005 - mae: 5.3762 - val_loss: 219.8065 - val_mae: 12.0869
# Epoch 189/200
# 7/7 [==============================] - 0s 9ms/step - loss: 53.4702 - mae: 5.4155 - val_loss: 236.5089 - val_mae: 12.4912
# Epoch 190/200
# 7/7 [==============================] - 0s 9ms/step - loss: 56.1410 - mae: 5.5261 - val_loss: 266.6137 - val_mae: 12.5268
# Epoch 191/200
# 7/7 [==============================] - 0s 8ms/step - loss: 58.7798 - mae: 5.6317 - val_loss: 240.2003 - val_mae: 11.9472
# Epoch 192/200
# 7/7 [==============================] - 0s 10ms/step - loss: 69.6016 - mae: 5.9896 - val_loss: 218.6764 - val_mae: 12.0650
# Epoch 193/200
# 7/7 [==============================] - 0s 15ms/step - loss: 73.9241 - mae: 6.3806 - val_loss: 247.1339 - val_mae: 12.5378
# Epoch 194/200
# 7/7 [==============================] - 0s 9ms/step - loss: 73.8331 - mae: 6.0119 - val_loss: 256.3688 - val_mae: 12.4162
# Epoch 195/200
# 7/7 [==============================] - 0s 11ms/step - loss: 71.1166 - mae: 6.2114 - val_loss: 277.7952 - val_mae: 12.7634
# Epoch 196/200
# 7/7 [==============================] - 0s 11ms/step - loss: 66.2033 - mae: 5.7264 - val_loss: 258.7822 - val_mae: 12.5967
# Epoch 197/200
# 7/7 [==============================] - 0s 10ms/step - loss: 54.3926 - mae: 5.3950 - val_loss: 275.5529 - val_mae: 12.7768
# Epoch 198/200
# 7/7 [==============================] - 0s 10ms/step - loss: 57.3954 - mae: 5.3747 - val_loss: 259.8612 - val_mae: 12.3617
# Epoch 199/200
# 7/7 [==============================] - 0s 11ms/step - loss: 55.4414 - mae: 5.5274 - val_loss: 280.5197 - val_mae: 12.9756
# Epoch 200/200
# 7/7 [==============================] - 0s 10ms/step - loss: 56.6380 - mae: 5.4423 - val_loss: 294.8077 - val_mae: 13.0738
# 1/1 [==============================] - 0s 212ms/step

# %% [markdown]
# ## Lab work: Air Pollution Forecasting
#
# This is a dataset that reports on the weather and the level of pollution each hour for five years at the US embassy in Beijing, China.
#
# The data includes the date-time, the pollution called PM2.5 concentration, and the weather information including dew point, temperature, pressure, wind direction, wind speed and the cumulative number of hours of snow and rain. The complete feature list in the raw data is as follows:
#
# 1. No: row number
# 1. year: year of data in this row
# 1. month: month of data in this row
# 1. day: day of data in this row
# 1. hour: hour of data in this row
# 1. pm2.5: PM2.5 concentration
# 1. DEWP: Dew Point
# 1. TEMP: Temperature
# 1. PRES: Pressure
# 1. cbwd: Combined wind direction
# 1. Iws: Cumulated wind speed
# 1. Is: Cumulated hours of snow
# 1. Ir: Cumulated hours of rain
#
# We can use this data and frame a forecasting problem where, given the weather conditions and pollution for prior hours, we forecast the pollution at the next hour.
#
# This dataset can be used to frame other forecasting problems.

# %% [markdown]
# ## Load the data

# %%
DATAPATH = "https://www.i3s.unice.fr/~riveill/dataset/pollution.csv"

# %%
# Read the dataset
data = pd.read_csv(DATAPATH, sep=",", header=0, index_col=0)
data.head()
# Out:
#                      pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79     0     0
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68     0     0
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57     0     0
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36     1     0
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25     2     0

# %%
plt.figure()
for i, column in enumerate(data.columns):
    plt.subplot(len(data.columns), 1, i+1)
    plt.plot(data[column].to_numpy())
    plt.title(column, y=0.5, loc='right')
plt.show()

# %% [markdown]
# ### Construct the dataset

# %% [markdown]
# The first step is to prepare the pollution dataset for the LSTM.
#
# This involves framing the dataset as a supervised learning problem and normalizing the input variables.
#
# We will frame the supervised learning problem as predicting the pollution at the current hour (t) given the pollution measurement and weather conditions at the prior time step.

# %%
n_features = data.shape[1] # for multivariate time series
n_in = 6
n_out = 1
output = ["pollution"]

n_features
# Out:
# 8

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * using `series_to_supervised` function build the dataset
# </font>

# %%
dataset = series_to_supervised(data, n_in, n_out, output)
dataset.head()
# Out:
#                      pollution(t-6)  dew(t-6)  temp(t-6)  press(t-6)  \
# date
# 2010-01-02 06:00:00           129.0     -16.0       -4.0      1020.0
# 2010-01-02 07:00:00           148.0     -15.0       -4.0      1020.0
# 2010-01-02 08:00:00           159.0     -11.0       -5.0      1021.0
# 2010-01-02 09:00:00           181.0      -7.0       -5.0      1022.0
# 2010-01-02 10:00:00           138.0      -7.0       -5.0      1022.0
#
#                     wnd_dir(t-6)  wnd_spd(t-6)  snow(t-6)  rain(t-6)  \
# date
# 2010-01-02 06:00:00           SE          1.79        0.0        0.0
# 2010-01-02 07:00:00           SE          2.68        0.0        0.0
# 2010-01-02 08:00:00           SE          3.57        0.0        0.0
# 2010-01-02 09:00:00           SE          5.36        1.0        0.0
# 2010-01-02 10:00:00           SE          6.25        2.0        0.0
#
#                      pollution(t-5)  dew(t-5)  ...  rain(t-2)  pollution(t-1)  \
# date                                           ...
# 2010-01-02 06:00:00           148.0     -15.0  ...        0.0           109.0
# 2010-01-02 07:00:00           159.0     -11.0  ...        0.0           105.0
# 2010-01-02 08:00:00           181.0      -7.0  ...        0.0           124.0
# 2010-01-02 09:00:00           138.0      -7.0  ...        0.0           120.0
# 2010-01-02 10:00:00           109.0      -7.0  ...        0.0           132.0
#
#                     dew(t-1)  temp(t-1)  press(t-1)  wnd_dir(t-1)  \
# date
# 2010-01-02 06:00:00     -7.0       -6.0      1022.0            SE
# 2010-01-02 07:00:00     -7.0       -6.0      1023.0            SE
# 2010-01-02 08:00:00     -7.0       -5.0      1024.0            SE
# 2010-01-02 09:00:00     -8.0       -6.0      1024.0            SE
# 2010-01-02 10:00:00     -7.0       -5.0      1025.0            SE
#
#                      wnd_spd(t-1)  snow(t-1)  rain(t-1)  pollution(t)
# date
# 2010-01-02 06:00:00          7.14        3.0        0.0         105.0
# 2010-01-02 07:00:00          8.93        4.0        0.0         124.0
# 2010-01-02 08:00:00         10.72        0.0        0.0         120.0
# 2010-01-02 09:00:00         12.51        0.0        0.0         132.0
# 2010-01-02 10:00:00         14.30        0.0        0.0         140.0
#
# [5 rows x 49 columns]

# %%
dataset.dtypes
# Out:
# pollution(t-6)    float64
# dew(t-6)          float64
# temp(t-6)         float64
# press(t-6)        float64
# wnd_dir(t-6)       object
# wnd_spd(t-6)      float64
# snow(t-6)         float64
# rain(t-6)         float64
# pollution(t-5)    float64
# dew(t-5)          float64
# temp(t-5)         float64
# press(t-5)        float64
# wnd_dir(t-5)       object
# wnd_spd(t-5)      float64
# snow(t-5)         float64
# rain(t-5)         float64
# pollution(t-4)    float64
# dew(t-4)          float64
# temp(t-4)         float64
# press(t-4)        float64
# wnd_dir(t-4)       object
# wnd_spd(t-4)      float64
# snow(t-4)         float64
# rain(t-4)         float64
# pollution(t-3)    float64
# dew(t-3)          float64
# temp(t-3)         float64
# press(t-3)        float64
# wnd_dir(t-3)       object
# wnd_spd(t-3)      float64
# snow(t-3)         float64
# rain(t-3)         float64
# pollution(t-2)    float64
# dew(t-2)          float64
# temp(t-2)         float64
# press(t-2)        float64
# wnd_dir(t-2)       object
# wnd_spd(t-2)      float64
# snow(t-2)         float64
# rain(t-2)         float64
# pollution(t-1)    float64
# dew(t-1)          float64
# temp(t-1)         float64
# press(t-1)        float64
# wnd_dir(t-1)       object
# wnd_spd(t-1)      float64
# snow(t-1)         float64
# rain(t-1)         float64
# pollution(t)      float64
# dtype: object

# %% [markdown]
# <font color='blue'>
# <bold>dataset.dtypes gives the following result for me</bold>
#
# <pre>
# pollution(t-6)    float64
# dew(t-6)          float64
# temp(t-6)         float64
# press(t-6)        float64
# wnd_dir(t-6)       object
# wnd_spd(t-6)      float64
# snow(t-6)         float64
# rain(t-6)         float64
# pollution(t-5)    float64
# dew(t-5)          float64
# temp(t-5)         float64
# press(t-5)        float64
# wnd_dir(t-5)       object
# wnd_spd(t-5)      float64
# snow(t-5)         float64
# rain(t-5)         float64
# pollution(t-4)    float64
# dew(t-4)          float64
# temp(t-4)         float64
# press(t-4)        float64
# wnd_dir(t-4)       object
# wnd_spd(t-4)      float64
# snow(t-4)         float64
# rain(t-4)         float64
# pollution(t-3)    float64
# dew(t-3)          float64
# temp(t-3)         float64
# press(t-3)        float64
# wnd_dir(t-3)       object
# wnd_spd(t-3)      float64
# snow(t-3)         float64
# rain(t-3)         float64
# pollution(t-2)    float64
# dew(t-2)          float64
# temp(t-2)         float64
# press(t-2)        float64
# wnd_dir(t-2)       object
# wnd_spd(t-2)      float64
# snow(t-2)         float64
# rain(t-2)         float64
# pollution(t-1)    float64
# dew(t-1)          float64
# temp(t-1)         float64
# press(t-1)        float64
# wnd_dir(t-1)       object
# wnd_spd(t-1)      float64
# snow(t-1)         float64
# rain(t-1)         float64
# pollution(t)      float64
# dtype: object
# <pre>
# </font>

# %% [markdown]
# First, we must split the prepared dataset into train and test sets. To speed up the training of the model for this demonstration, we will only fit the model on the first year of data, then evaluate it on the remaining 4 years of data.
#
# The example below splits the dataset into train and test sets, then splits the train and test sets into input and output variables. Finally, the inputs (X) are reshaped into the 3D format expected by LSTMs, namely [samples, timesteps, features].

# %%
# get the values
values = dataset.values

# split into train and test sets
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
val = values[n_train_hours:2*n_train_hours, :]
test = values[2*n_train_hours:, :]

# split into input and outputs
train_X, train_y = train[:, :-n_out], np.array(train[:, -n_out], dtype="float64")
val_X, val_y = val[:, :-n_out], np.array(val[:, -n_out], dtype="float64")
test_X, test_y = test[:, :-n_out], np.array(test[:, -n_out], dtype="float64")

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_in, n_features))
val_X = val_X.reshape((val_X.shape[0], n_in, n_features))
test_X = test_X.reshape((test_X.shape[0], n_in, n_features))
train_X.shape, train_y.shape
# Out:
# ((8760, 6, 8), (8760,))

# %% [markdown]
# ### Encode and normalize dataset

# %% [markdown]
# Data encoding and normalization
# * The wind direction feature is label encoded (integer encoded).
# * All features are normalized
#
# And then the dataset is transformed into a supervised learning problem. The weather variables for the hour to be predicted (t) are then removed.

# %%
numeric_features = [i for i, t in enumerate(dataset.dtypes[:-n_out]) if t in ['float64', 'int32']]
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = [i for i in range(len(dataset.columns)-n_out) if i not in numeric_features]
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

train_X_enc = preprocessor.fit_transform(train_X.reshape(len(train_X), -1)).reshape(len(train_X), n_in, -1)
val_X_enc = preprocessor.fit_transform(val_X.reshape(len(val_X), -1)).reshape(len(val_X), n_in, -1)
test_X_enc = preprocessor.transform(test_X.reshape(len(test_X), -1)).reshape(len(test_X), n_in, -1)
                                                                                    
n_features = train_X_enc.shape[2] # Change with oneHotEncode
n_features
# Out:
# 11

# %% [markdown]
# Running the code below prepare the data. Executing the next cell, prints the first 5 rows of the transformed dataset. We can see the 8 input variables (input series) and the 1 output variable (pollution level at the current hour).

# %% [markdown]
# ### Build, Compile, Fit, Predict and Evaluate a model
# <br>
# <font color='red'>
# $TO DO - Students$
#
# * Build your model
#     * Put the number of hidden layers you want. If possible more than one.
# </font>

# %%
LSTM_SIZE = 256

inputs = Input(shape=(n_in, n_features))
hidden = LSTM(LSTM_SIZE, activation='relu', return_sequences=False)(inputs)
outputs = Dense(n_out, activation='linear')(hidden)
model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 6, 11)]           0
#
#  lstm_10 (LSTM)              (None, 256)               274432
#
#  dense_6 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 274,689
# Trainable params: 274,689
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * Compile your model
# </font>

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * Fit your model using `EarlyStopping`
# </font>

# %%
model = build_and_fit(model, train_X_enc, train_y, val_X_enc, val_y, test_X_enc, test_y, patience=20)
# Out:
# Epoch 1/200
# 274/274 [==============================] - 10s 30ms/step - loss: 13343.8096 - mae: 83.4341 - val_loss: 8324.7725 - val_mae: 64.5070
# Epoch 2/200
# 274/274 [==============================] - 8s 30ms/step - loss: 6455.9673 - mae: 55.0103 - val_loss: 3997.6494 - val_mae: 44.0842
# Epoch 3/200
# 274/274 [==============================] - 9s 31ms/step - loss: 3595.3293 - mae: 40.7388 - val_loss: 3043.6895 - val_mae: 36.8882
# Epoch 4/200
# 274/274 [==============================] - 14s 52ms/step - loss: 2574.9695 - mae: 34.7355 - val_loss: 3012.5469 - val_mae: 35.3054
# Epoch 5/200
# 274/274 [==============================] - 9s 33ms/step - loss: 2342.3230 - mae: 33.2404 - val_loss: 3719.9387 - val_mae: 44.3921
# Epoch 6/200
# 274/274 [==============================] - 12s 43ms/step - loss: 1983.2582 - mae: 30.1638 - val_loss: 3534.9719 - val_mae: 44.9554
# Epoch 7/200
# 274/274 [==============================] - 12s 44ms/step - loss: 1790.7908 - mae: 28.4886 - val_loss: 3419.6621 - val_mae: 45.1674
# Epoch 8/200
# 274/274 [==============================] - 9s 32ms/step - loss: 1505.1403 - mae: 25.7545 - val_loss: 3111.6282 - val_mae: 42.6198
# Epoch 9/200
# 274/274 [==============================] - 11s 41ms/step - loss: 1354.4100 - mae: 24.0651 - val_loss: 2626.4600 - val_mae: 38.9283
# Epoch 10/200
# 274/274 [==============================] - 10s 38ms/step - loss: 1221.6785 - mae: 22.4502 - val_loss: 2331.5498 - val_mae: 35.7728
# Epoch 11/200
# 274/274 [==============================] - 9s 31ms/step - loss: 1167.5341 - mae: 21.6324 - val_loss: 2475.6624 - val_mae: 37.4262
# Epoch 12/200
# 274/274 [==============================] - 9s 34ms/step - loss: 1096.5532 - mae: 20.3343 - val_loss: 3107.0676 - val_mae: 41.3724
# Epoch 13/200
# 274/274 [==============================] - 8s 31ms/step - loss: 1057.4496 - mae: 19.5188 - val_loss: 2481.0828 - val_mae: 35.4169
# Epoch 14/200
# 274/274 [==============================] - 9s 34ms/step - loss: 1012.2475 - mae: 18.7312 - val_loss: 3357.3916 - val_mae: 41.7182
# Epoch 15/200
# 274/274 [==============================] - 9s 31ms/step - loss: 959.9261 - mae: 18.2429 - val_loss: 1816.1331 - val_mae: 31.0552
# Epoch 16/200
# 274/274 [==============================] - 9s 31ms/step - loss: 955.5251 - mae: 18.0586 - val_loss: 2449.0273 - val_mae: 35.4732
# Epoch 17/200
# 274/274 [==============================] - 8s 31ms/step - loss: 964.7471 - mae: 18.3860 - val_loss: 2676.6328 - val_mae: 37.7714
# Epoch 18/200
# 274/274 [==============================] - 8s 31ms/step - loss: 937.5027 - mae: 17.8815 - val_loss: 2983.9026 - val_mae: 40.5685
# Epoch 19/200
# 274/274 [==============================] - 9s 31ms/step - loss: 883.7939 - mae: 16.7847 - val_loss: 2067.1228 - val_mae: 33.0870
# Epoch 20/200
# 274/274 [==============================] - 9s 32ms/step - loss: 883.6157 - mae: 17.1298 - val_loss: 2541.4785 - val_mae: 38.6989
# Epoch 21/200
# 274/274 [==============================] - 8s 31ms/step - loss: 945.0235 - mae: 18.1612 - val_loss: 3198.3047 - val_mae: 42.8658
# Epoch 22/200
# 274/274 [==============================] - 9s 33ms/step - loss: 874.6201 - mae: 16.9400 - val_loss: 3537.1230 - val_mae: 44.0320
# Epoch 23/200
# 274/274 [==============================] - 9s 32ms/step - loss: 885.2180 - mae: 16.7994 - val_loss: 8117.4912 - val_mae: 67.7252
# Epoch 24/200
# 274/274 [==============================] - 9s 32ms/step - loss: 1207.7207 - mae: 20.7654 - val_loss: 1822.0259 - val_mae: 31.6694
# Epoch 25/200
# 274/274 [==============================] - 9s 32ms/step - loss: 1004.4171 - mae: 18.3659 - val_loss: 1785.8900 - val_mae: 32.4562
# Epoch 26/200
# 274/274 [==============================] - 8s 29ms/step - loss: 899.6832 - mae: 17.1061 - val_loss: 2461.5410 - val_mae: 38.1235
# Epoch 27/200
# 274/274 [==============================] - 9s 32ms/step - loss: 916.6225 - mae: 17.3056 - val_loss: 1180.4216 - val_mae: 24.7642
# Epoch 28/200
# 274/274 [==============================] - 9s 32ms/step - loss: 821.1073 - mae: 15.8881 - val_loss: 1708.5608 - val_mae: 30.9730
# Epoch 29/200
# 274/274 [==============================] - 8s 31ms/step - loss: 820.6870 - mae: 16.0218 - val_loss: 1801.6785 - val_mae: 32.0418
# Epoch 30/200
# 274/274 [==============================] - 8s 29ms/step - loss: 815.5178 - mae: 15.9841 - val_loss: 2049.7852 - val_mae: 34.6402
# Epoch 31/200
# 274/274 [==============================] - 9s 32ms/step - loss: 803.7399 - mae: 15.9326 - val_loss: 2080.5754 - val_mae: 34.9218
# Epoch 32/200
# 274/274 [==============================] - 15s 56ms/step - loss: 824.2310 - mae: 16.1319 - val_loss: 1789.5312 - val_mae: 30.7065
# Epoch 33/200
# 274/274 [==============================] - 12s 43ms/step - loss: 1046.6996 - mae: 18.7939 - val_loss: 3279.1746 - val_mae: 41.8699
# Epoch 34/200
# 274/274 [==============================] - 16s 59ms/step - loss: 926.1035 - mae: 16.8075 - val_loss: 2069.4307 - val_mae: 33.6987
# Epoch 35/200
# 274/274 [==============================] - 9s 32ms/step - loss: 789.7619 - mae: 15.6467 - val_loss: 1343.3065 - val_mae: 26.4455
# Epoch 36/200
# 274/274 [==============================] - 10s 35ms/step - loss: 749.0916 - mae: 15.1475 - val_loss: 1567.2134 - val_mae: 29.0209
# Epoch 37/200
# 274/274 [==============================] - 9s 34ms/step - loss: 735.6049 - mae: 15.1112 - val_loss: 1725.6389 - val_mae: 30.9385
# Epoch 38/200
# 274/274 [==============================] - 13s 47ms/step - loss: 749.7861 - mae: 15.3936 - val_loss: 1408.5598 - val_mae: 27.1798
# Epoch 39/200
# 274/274 [==============================] - 17s 61ms/step - loss: 753.0890 - mae: 15.4540 - val_loss: 2811.5786 - val_mae: 34.9101
# Epoch 40/200
# 274/274 [==============================] - 12s 44ms/step - loss: 869.4566 - mae: 17.3211 - val_loss: 1154.2900 - val_mae: 24.1140
# Epoch 41/200
# 274/274 [==============================] - 10s 36ms/step - loss: 730.4618 - mae: 15.2051 - val_loss: 1383.1240 - val_mae: 26.9893
# Epoch 42/200
# 274/274 [==============================] - 12s 44ms/step - loss: 734.4247 - mae: 15.0853 - val_loss: 1709.7957 - val_mae: 31.0476
# Epoch 43/200
# 274/274 [==============================] - 9s 34ms/step - loss: 739.2429 - mae: 15.4279 - val_loss: 2173.2529 - val_mae: 35.4350
# Epoch 44/200
# 274/274 [==============================] - 15s 55ms/step - loss: 732.4534 - mae: 15.0320 - val_loss: 1499.2091 - val_mae: 28.8300
# Epoch 45/200
# 274/274 [==============================] - 10s 35ms/step - loss: 703.8289 - mae: 15.2013 - val_loss: 1531.4845 - val_mae: 29.1552
# Epoch 46/200
# 274/274 [==============================] - 13s 46ms/step - loss: 715.4685 - mae: 15.4283 - val_loss: 1813.3940 - val_mae: 30.3303
# Epoch 47/200
# 274/274 [==============================] - 10s 38ms/step - loss: 744.9349 - mae: 15.8673 - val_loss: 2842.0693 - val_mae: 39.0328
# Epoch 48/200
# 274/274 [==============================] - 10s 35ms/step - loss: 742.7703 - mae: 15.6676 - val_loss: 1070.7056 - val_mae: 21.7916
# Epoch 49/200
# 274/274 [==============================] - 9s 32ms/step - loss: 655.7263 - mae: 14.5278 - val_loss: 1898.3896 - val_mae: 31.7796
# Epoch 50/200
# 274/274 [==============================] - 11s 42ms/step - loss: 667.0521 - mae: 14.8841 - val_loss: 1277.7383 - val_mae: 25.0865
# Epoch 51/200
# 274/274 [==============================] - 10s 37ms/step - loss: 644.1829 - mae: 14.5901 - val_loss: 1210.0266 - val_mae: 23.7806
# Epoch 52/200
# 274/274 [==============================] - 9s 33ms/step - loss: 640.3397 - mae: 14.5427 - val_loss: 1747.0140 - val_mae: 28.6163
# Epoch 53/200
# 274/274 [==============================] - 9s 33ms/step - loss: 689.3669 - mae: 15.2723 - val_loss: 4255.1274 - val_mae: 47.3862
# Epoch 54/200
# 274/274 [==============================] - 10s 35ms/step - loss: 723.7484 - mae: 15.9233 - val_loss: 2106.3855 - val_mae: 32.5073
# Epoch 55/200
# 274/274 [==============================] - 8s 30ms/step - loss: 662.3865 - mae: 14.7137 - val_loss: 1258.3573 - val_mae: 24.4945
# Epoch 56/200
# 274/274 [==============================] - 8s 30ms/step - loss: 599.8342 - mae: 14.2319 - val_loss: 1869.0115 - val_mae: 30.5865
# Epoch 57/200
# 274/274 [==============================] - 9s 33ms/step - loss: 673.4833 - mae: 15.2714 - val_loss: 1155.1910 - val_mae: 22.8177
# Epoch 58/200
# 274/274 [==============================] - 9s 33ms/step - loss: 625.1672 - mae: 14.4455 - val_loss: 1468.4894 - val_mae: 26.7388
# Epoch 59/200
# 274/274 [==============================] - 8s 31ms/step - loss: 603.9476 - mae: 14.1930 - val_loss: 1525.9265 - val_mae: 27.7762
# Epoch 60/200
# 274/274 [==============================] - 9s 31ms/step - loss: 578.9507 - mae: 13.8517 - val_loss: 1530.9729 - val_mae: 27.2765
# Epoch 61/200
# 274/274 [==============================] - 10s 36ms/step - loss: 594.6113 - mae: 14.2662 - val_loss: 1455.6917 - val_mae: 27.0299
# Epoch 62/200
# 274/274 [==============================] - 9s 33ms/step - loss: 590.4507 - mae: 14.0192 - val_loss: 1700.9242 - val_mae: 27.4913
# Epoch 63/200
# 274/274 [==============================] - 9s 32ms/step - loss: 605.2731 - mae: 14.5335 - val_loss: 2010.4893 - val_mae: 33.1402
# Epoch 64/200
# 274/274 [==============================] - 10s 35ms/step - loss: 637.7501 - mae: 14.6747 - val_loss: 1486.4919 - val_mae: 26.1996
# Epoch 65/200
# 274/274 [==============================] - 9s 32ms/step - loss: 654.2781 - mae: 14.8348 - val_loss: 3300.0122 - val_mae: 41.2031
# Epoch 66/200
# 274/274 [==============================] - 9s 35ms/step - loss: 642.5536 - mae: 14.8847 - val_loss: 1724.2596 - val_mae: 29.5724
# Epoch 67/200
# 274/274 [==============================] - 10s 37ms/step - loss: 595.5982 - mae: 14.0149 - val_loss: 1617.0598 - val_mae: 28.6585
# Epoch 68/200
# 274/274 [==============================] - 9s 33ms/step - loss: 554.7085 - mae: 13.6892 - val_loss: 1403.7653 - val_mae: 26.1657
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f418457f8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 822/822 [==============================] - 7s 8ms/step

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * Use your model to predict test set data
# </font>

# %%
# make a prediction
y_test_pred = model.predict(test_X_enc)
y_test_pred

# %%
y_test_pred.shape
# Out:
# (26274, 1)

# %% [markdown]
# <font color='red'>
# $TO DO - Students$
#
# * Evaluate your model with RMSE
# </font>

# %%
# calculate RMSE
rmse = np.sqrt(np.mean((y_test_pred.flatten()-test_y.flatten())**2))
'Test RMSE: %.3f' % rmse
# Out:
# 'Test RMSE: 33.172'

# %% [markdown]
# ### Predict next day
#
# Generally, what we are trying to predict is a pollution indicator for the day or per 12-hour period.
#
# Modify the datasets to create a new column giving a pollution indicator per half day: little pollution, moderate pollution, heavy pollution.
